# %% [markdown]
# # L5: Inference

# %%
# Warning control
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np

from sentence_transformers import SentenceTransformer
from transformers import AutoTokenizer, \
                         DPRContextEncoder, DPRQuestionEncoder

import logging
logging.getLogger("transformers.modeling_utils").setLevel(logging.ERROR)

# %%
from pathlib import Path
hf_model_dir = Path("D:/LocalLLama/hf_models")

# %%
def cosine_similarity_matrix(features):
    norms = np.linalg.norm(features, axis=1, keepdims=True)
    normalized_features = features / norms
    similarity_matrix = np.inner(normalized_features, normalized_features)
    rounded_similarity_matrix = np.round(similarity_matrix, 4)
    return rounded_similarity_matrix

# %% [markdown]
# ## Pure similarity

# %%
answers = [
    "What is the tallest mountain in the world?",
    "The tallest mountain in the world is Mount Everest.",
    "Mount Shasta",
    "I like my hike in the mountains",
    "I am going to a yoga class"
]

question = 'What is the tallest mountain in the world?'

# %%
model = SentenceTransformer("sentence-transformers/all-MiniLM-L6-v2", cache_folder=hf_model_dir)
question_embedding = list(model.encode(question))

sim = []
for answer in answers:
    answer_embedding = list(model.encode(answer))
    sim.append(cosine_similarity_matrix(np.stack([question_embedding, answer_embedding]))[0,1])

print(sim)
best_inx = np.argmax(sim)
print(f"Question = {question}")
print(f"Best answer = {answers[best_inx]}")
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# The following layers were not sharded: encoder.layer.*.intermediate.dense.bias, embeddings.position_embeddings.weight, encoder.layer.*.attention.output.LayerNorm.bias, encoder.layer.*.attention.self.query.bias, encoder.layer.*.attention.self.key.bias, embeddings.LayerNorm.bias, encoder.layer.*.attention.self.key.weight, pooler.dense.weight, embeddings.word_embeddings.weight, encoder.layer.*.output.LayerNorm.weight, encoder.layer.*.attention.output.LayerNorm.weight, encoder.layer.*.attention.self.value.bias, encoder.layer.*.output.LayerNorm.bias, encoder.layer.*.intermediate.dense.weight, encoder.layer.*.attention.output.dense.weight, encoder.layer.*.output.dense.bias, pooler.dense.bias, encoder.layer.*.attention.self.query.weight, encoder.layer.*.output.dense.weight, encoder.layer.*.attention.self.value.weight, encoder.layer.*.attention.output.dense.bias, embeddings.LayerNorm.weight, embeddings.token_type_embeddings.weight
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# [np.float32(1.0), np.float32(0.7976), np.float32(0.4001), np.float32(0.3559), np.float32(0.0972)]
# Question = What is the tallest mountain in the world?
# Best answer = What is the tallest mountain in the world?

# %% [markdown]
# ## Dual-Encoder inference

# %%
answer_tokenizer = AutoTokenizer \
                   .from_pretrained("facebook/dpr-ctx_encoder-multiset-base",cache_dir=hf_model_dir)
answer_encoder = DPRContextEncoder \
                   .from_pretrained("facebook/dpr-ctx_encoder-multiset-base",cache_dir=hf_model_dir)

question_tokenizer = AutoTokenizer \
                   .from_pretrained("facebook/dpr-question_encoder-multiset-base",cache_dir=hf_model_dir)
question_encoder = DPRQuestionEncoder \
                   .from_pretrained("facebook/dpr-question_encoder-multiset-base",cache_dir=hf_model_dir)
# Out:
# tokenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/492 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/438M [00:00<?, ?B/s]
# The following layers were not sharded: ctx_encoder.bert_model.encoder.layer.*.attention.output.LayerNorm.weight, ctx_encoder.bert_model.encoder.layer.*.attention.output.dense.weight, ctx_encoder.bert_model.encoder.layer.*.intermediate.dense.weight, ctx_encoder.bert_model.encoder.layer.*.output.dense.weight, ctx_encoder.bert_model.embeddings.position_embeddings.weight, ctx_encoder.bert_model.encoder.layer.*.attention.self.value.weight, ctx_encoder.bert_model.encoder.layer.*.attention.output.LayerNorm.bias, ctx_encoder.bert_model.encoder.layer.*.output.dense.bias, ctx_encoder.bert_model.encoder.layer.*.attention.self.key.bias, ctx_encoder.bert_model.encoder.layer.*.intermediate.dense.bias, ctx_encoder.bert_model.encoder.layer.*.attention.self.query.bias, ctx_encoder.bert_model.encoder.layer.*.output.LayerNorm.weight, ctx_encoder.bert_model.encoder.layer.*.attention.self.value.bias, ctx_encoder.bert_model.encoder.layer.*.output.LayerNorm.bias, ctx_encoder.bert_model.embeddings.token_type_embeddings.weight, ctx_encoder.bert_model.encoder.layer.*.attention.self.key.weight, ctx_encoder.bert_model.encoder.layer.*.attention.output.dense.bias, ctx_encoder.bert_model.embeddings.word_embeddings.weight, ctx_encoder.bert_model.encoder.layer.*.attention.self.query.weight, ctx_encoder.bert_model.embeddings.LayerNorm.weight, ctx_encoder.bert_model.embeddings.LayerNorm.bias
# tokenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/493 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/438M [00:00<?, ?B/s]
# The following layers were not sharded: question_encoder.bert_model.embeddings.LayerNorm.bias, question_encoder.bert_model.encoder.layer.*.attention.self.key.weight, question_encoder.bert_model.encoder.layer.*.output.LayerNorm.weight, question_encoder.bert_model.encoder.layer.*.attention.output.LayerNorm.bias, question_encoder.bert_model.encoder.layer.*.attention.output.dense.weight, question_encoder.bert_model.encoder.layer.*.attention.self.query.weight, question_encoder.bert_model.encoder.layer.*.attention.self.value.bias, question_encoder.bert_model.encoder.layer.*.output.dense.bias, question_encoder.bert_model.encoder.layer.*.output.dense.weight, question_encoder.bert_model.encoder.layer.*.attention.output.dense.bias, question_encoder.bert_model.embeddings.word_embeddings.weight, question_encoder.bert_model.embeddings.token_type_embeddings.weight, question_encoder.bert_model.encoder.layer.*.output.LayerNorm.bias, question_encoder.bert_model.encoder.layer.*.attention.self.key.bias, question_encoder.bert_model.encoder.layer.*.attention.self.query.bias, question_encoder.bert_model.encoder.layer.*.attention.self.value.weight, question_encoder.bert_model.embeddings.position_embeddings.weight, question_encoder.bert_model.encoder.layer.*.intermediate.dense.weight, question_encoder.bert_model.encoder.layer.*.intermediate.dense.bias, question_encoder.bert_model.encoder.layer.*.attention.output.LayerNorm.weight, question_encoder.bert_model.embeddings.LayerNorm.weight
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]

# %%
# Compute the question embeddings
question_tokens = question_tokenizer(question, return_tensors="pt")["input_ids"]
question_embedding = question_encoder(question_tokens).pooler_output.flatten().tolist()
print(question_embedding[:10], len(question_embedding))
# Out:
# [0.07758226245641708, 0.2517254948616028, 0.18663933873176575, 0.221201092004776, 0.026415381580591202, -0.15785622596740723, 0.3276026248931885, 0.2673284411430359, -0.08503060042858124, 0.12929478287696838] 768

# %%
sim = []
for answer in answers:
    answer_tokens = answer_tokenizer(answer, return_tensors="pt")["input_ids"]
    answer_embedding = answer_encoder(answer_tokens).pooler_output.flatten().tolist()
    sim.append(cosine_similarity_matrix(np.stack([question_embedding, answer_embedding]))[0,1])

print(sim)
best_inx = np.argmax(sim)
print(f"Question = {question}")
print(f"Best answer = {answers[best_inx]}")
# Out:
# [np.float64(0.6253), np.float64(0.7472), np.float64(0.5506), np.float64(0.3687), np.float64(0.25)]
# Question = What is the tallest mountain in the world?
# Best answer = The tallest mountain in the world is Mount Everest.
