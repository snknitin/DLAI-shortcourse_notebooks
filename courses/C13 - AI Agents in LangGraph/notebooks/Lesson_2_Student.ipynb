# %% [markdown]
# # Lesson 2 : LangGraph Components

# %%
from dotenv import load_dotenv
_ = load_dotenv()

# %%
from langgraph.graph import StateGraph, END
from typing import TypedDict, Annotated
import operator
from langchain_core.messages import AnyMessage, SystemMessage, HumanMessage, ToolMessage
from langchain_openai import ChatOpenAI
from langchain_community.tools.tavily_search import TavilySearchResults

# %%
tool = TavilySearchResults(max_results=4) #increased number of results
print(type(tool))
print(tool.name)
# Out:
# <class 'langchain_community.tools.tavily_search.tool.TavilySearchResults'>
# tavily_search_results_json
# C:\Users\snkni\AppData\Local\Temp\ipykernel_32424\144666821.py:1: LangChainDeprecationWarning: The class `TavilySearchResults` was deprecated in LangChain 0.3.25 and will be removed in 1.0. An updated version of the class exists in the `langchain-tavily package and should be used instead. To use it run `pip install -U `langchain-tavily` and import as `from `langchain_tavily import TavilySearch``.
#   tool = TavilySearchResults(max_results=4) #increased number of results

# %% [markdown]
# > If you are not familiar with python typing annotation, you can refer to the [python documents](https://docs.python.org/3/library/typing.html).

# %%
class AgentState(TypedDict):
    messages: Annotated[list[AnyMessage], operator.add]

# %% [markdown]
# > Note: in `take_action` below, some logic was added to cover the case that the LLM returned a non-existent tool name. Even with function calling, LLMs can still occasionally hallucinate. Note that all that is done is instructing the LLM to try again! An advantage of an agentic organization.

# %%
class Agent:

    def __init__(self, model, tools, system=""):
        self.system = system
        graph = StateGraph(AgentState)
        graph.add_node("llm", self.call_openai)
        graph.add_node("action", self.take_action)
        graph.add_conditional_edges(
            "llm",
            self.exists_action,
            {True: "action", False: END}
        )
        graph.add_edge("action", "llm")
        graph.set_entry_point("llm")
        self.graph = graph.compile()
        self.tools = {t.name: t for t in tools}
        self.model = model.bind_tools(tools)

    def exists_action(self, state: AgentState):
        result = state['messages'][-1]
        return len(result.tool_calls) > 0

    def call_openai(self, state: AgentState):
        messages = state['messages']
        if self.system:
            messages = [SystemMessage(content=self.system)] + messages
        message = self.model.invoke(messages)
        return {'messages': [message]}

    def take_action(self, state: AgentState):
        tool_calls = state['messages'][-1].tool_calls
        results = []
        for t in tool_calls:
            print(f"Calling: {t}")
            if not t['name'] in self.tools:      # check for bad tool name from LLM
                print("\n ....bad tool name....")
                result = "bad tool name, retry"  # instruct LLM to retry if bad
            else:
                result = self.tools[t['name']].invoke(t['args'])
            results.append(ToolMessage(tool_call_id=t['id'], name=t['name'], content=str(result)))
        print("Back to the model!")
        return {'messages': results}

# %%
prompt = """You are a smart research assistant. Use the search engine to look up information. \
You are allowed to make multiple calls (either together or in sequence). \
Only look up information when you are sure of what you want. \
If you need to look up some information before asking a follow up question, you are allowed to do that!
"""

model = ChatOpenAI(model="gpt-3.5-turbo")  #reduce inference cost
abot = Agent(model, [tool], system=prompt)

# %%
from IPython.display import Image

Image(abot.graph.get_graph().draw_mermaid_png())

# %%
messages = [HumanMessage(content="What is the weather in sf?")]
result = abot.graph.invoke({"messages": messages})
# Out:
# Calling: {'name': 'tavily_search_results_json', 'args': {'query': 'weather in San Francisco'}, 'id': 'call_mVVxYTfa8cW5VBHO649nrZ9w', 'type': 'tool_call'}
# Back to the model!

# %%
result
# Out:
# {'messages': [HumanMessage(content='What is the weather in sf?', additional_kwargs={}, response_metadata={}),
#   AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 21, 'prompt_tokens': 153, 'total_tokens': 174, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-DSe4UsrV9o1mARBbiA40WJxQUNvkV', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019d7122-9c48-7462-b7d6-98b01c1e7e99-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in San Francisco'}, 'id': 'call_mVVxYTfa8cW5VBHO649nrZ9w', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 153, 'output_tokens': 21, 'total_tokens': 174, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#   ToolMessage(content="[{'title': 'San Francisco weather in April 2026 | Weather25.com', 'url': 'https://www.weather25.com/north-america/usa/california/san-francisco?page=month&month=April', 'content': '| September | 77° / 57° | 0 | 30 | 0 | 0.16 in | Perfect | San Francisco in September |\\n| October | 73° / 55° | 1 | 30 | 0 | 1.02 in | Perfect | San Francisco in October |\\n| November | 64° / 50° | 3 | 27 | 0 | 1.46 in | Good | San Francisco in November |\\n| December | 57° / 46° | 4 | 27 | 0 | 2.17 in | Good | San Francisco in December | [...] Click on a day for an hourly weather forecast\\n\\nDiscover more\\n\\nWeather\\n\\nDemographics\\n\\nGeographic Reference\\n\\nWeather Alert Service\\n\\nTravel booking services\\n\\nPrecision Location Forecasts\\n\\nTravel Weather Guides\\n\\nLocal Weather Widgets\\n\\n## Explore the weather in San Francisco in other months\\n\\n01 January02 February03 March04 April05 May06 June07 July08 August09 September10 October11 November12 December\\n\\n## San Francisco annual weather [...] | 19 Image 46: Sunny 55°/46° | 20 Image 47: Sunny 59°/46° | 21 Image 48: Sunny 60°/51° | 22 Image 49: Partly cloudy 60°/50° | 23 Image 50: Partly cloudy 60°/50° | 24 Image 51: Sunny 60°/50° | 25 Image 52: Overcast 59°/50° |\\n| 26 Image 53: Partly cloudy 62°/50° | 27 Image 54: Partly cloudy 62°/50° | 28 Image 55: Sunny 64°/51° | 29 Image 56: Overcast 62°/50° | 30 Image 57: Overcast 62°/50° |  |  |', 'score': 0.90907925}, {'title': 'Weather San Francisco in April 2026: Temperature & Climate', 'url': 'https://en.climate-data.org/north-america/united-states-of-america/california/san-francisco-385/t/april-4/', 'content': 'The warmest water temperature of the month is recorded on 09.04, averaging 11.4°C | 52.4°F.\\n\\n#### When is the minimum water temperature reached in San Francisco during April?\\n\\nThe coldest water temperature of the month is recorded on 15.04, averaging 11.1°C | 52°F.\\n\\n#### What is the pattern of water temperature in San Francisco throughout April?\\n\\nAt the beginning of the month, average sea temperatures are 11.3°C | 52.3°F.\\nThey fall slightly to 11.2°C | 52.2°F around mid-month and rise to 11.2°C | 52.2°F by month’s end.\\n\\n#### What 10-day window in April brings the highest water temperatures to San Francisco?\\n\\nBetween 1-10, the water temperature remains highest, averaging 11.3°C | 52.3°F over 10 days.\\n\\n#### What 10-day window in April sees the coldest water in San Francisco? [...] | August | 16.7  (62.1) | 13.3  (55.9) | 22.2  (71.9) | 2  (0.1) | 74% | 0 | 7.0 |\\n| September | 17.1  (62.7) | 13.1  (55.6) | 23.1  (73.6) | 3  (0.1) | 71% | 1 | 8.0 |\\n| October | 15.7  (60.2) | 11.9  (53.4) | 21.3  (70.3) | 25  (1) | 70% | 2 | 7.0 |\\n| November | 12.4  (54.4) | 9  (48.2) | 17.1  (62.8) | 57  (2.2) | 76% | 4 | 7.0 |\\n| December | 9.9  (49.8) | 6.8  (44.2) | 13.9  (57.1) | 111  (4.4) | 78% | 8 | 6.0 | [...] | August | 16.7  (62.1) | 13.3  (55.9) | 22.2  (71.9) | 2  (0.1) | 74% | 0 | 7.0 |\\n| September | 17.1  (62.7) | 13.1  (55.6) | 23.1  (73.6) | 3  (0.1) | 71% | 1 | 8.0 |\\n| October | 15.7  (60.2) | 11.9  (53.4) | 21.3  (70.3) | 25  (1) | 70% | 2 | 7.0 |\\n| November | 12.4  (54.4) | 9  (48.2) | 17.1  (62.8) | 57  (2.2) | 76% | 4 | 7.0 |\\n| December | 9.9  (49.8) | 6.8  (44.2) | 13.9  (57.1) | 111  (4.4) | 78% | 8 | 6.0 |', 'score': 0.826278}, {'title': 'San Francisco 2026 Past Weather (California, United States)', 'url': 'https://weatherspark.com/h/y/557/2026/Historical-Weather-during-2026-in-San-Francisco-California-United-States', 'content': 'in 2026 in San Francisco Link  Download  Compare  Averages  History:202620252024202320222021202020192018    0 mph calm   1 mph light air   4 mph light breeze   8 mph gentle breeze   13 mph moderate breeze   18 mph fresh breeze   25 mph strong breeze   31 mph near gale   39 mph gale   47 mph strong gale   55 mph storm   64 mph violent storm   73 mph hurricane force  The hourly reported wind speed, color coded into bands ac ...
#   AIMessage(content='The weather in San Francisco is currently partly cloudy with a temperature of around 60°F. You can find more detailed hourly weather forecasts by clicking on a specific day on websites like Weather25.com.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 40, 'prompt_tokens': 2484, 'total_tokens': 2524, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-DSe4Xzom6QXxY6xMx8pOW7DfYJlTd', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d7122-a76b-75c2-9e69-68d931a27e0e-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 2484, 'output_tokens': 40, 'total_tokens': 2524, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}

# %%
result['messages'][-1].content
# Out:
# 'The weather in San Francisco is currently partly cloudy with a temperature of around 60°F. You can find more detailed hourly weather forecasts by clicking on a specific day on websites like Weather25.com.'

# %%
messages = [HumanMessage(content="What is the weather in SF and LA?")]
result = abot.graph.invoke({"messages": messages})
# Out:
# Calling: {'name': 'tavily_search_results_json', 'args': {'query': 'current weather in San Francisco'}, 'id': 'call_z9rBKw24qMb6HuxEmsTkJDyq', 'type': 'tool_call'}
# Calling: {'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Los Angeles'}, 'id': 'call_l9qq7RptmHzqldnM5sEZmbZU', 'type': 'tool_call'}
# Back to the model!

# %%
result['messages'][-1].content
# Out:
# 'The current weather in San Francisco is around 17°C with daytime temperatures usually reaching 22°C in April. There are about 10 hours of bright sunshine per day in April, with an average of 40 mm of rainfall in the month.\n\nIn Los Angeles, the weather is comfortable with temperatures ranging from 13°C to 24°C in April. Expect a few rainy days but usually not more than 3. The weather forecast for Los Angeles in April 2026 includes partly cloudy, overcast, and sunny conditions.'

# %%
# Note, the query was modified to produce more consistent results.
# Results may vary per run and over time as search information and models change.

query = "Who won the super bowl in 2024? In what state is the winning team headquarters located? \
What is the GDP of that state? Answer each question."
messages = [HumanMessage(content=query)]

model = ChatOpenAI(model="gpt-4o")  # requires more advanced model
abot = Agent(model, [tool], system=prompt)
result = abot.graph.invoke({"messages": messages})
# Out:
# Calling: {'name': 'tavily_search_results_json', 'args': {'query': 'Super Bowl 2024 winner'}, 'id': 'call_CrDAXG7o7f3LDUDhcsVfRUDv', 'type': 'tool_call'}
# Back to the model!
# Calling: {'name': 'tavily_search_results_json', 'args': {'query': 'Kansas City Chiefs headquarters location'}, 'id': 'call_aMsJ3SNW55LXoXDU3YwNhgSe', 'type': 'tool_call'}
# Back to the model!
# Calling: {'name': 'tavily_search_results_json', 'args': {'query': 'Kansas GDP 2024'}, 'id': 'call_jvtI0vufOK7V1Brp6ulfWUcj', 'type': 'tool_call'}
# Back to the model!

# %%
print(result['messages'][-1].content)
# Out:
# 1. The Kansas City Chiefs won the Super Bowl in 2024.
#
# 2. The headquarters of the Kansas City Chiefs is located in Olathe, Kansas.
#
# 3. The GDP of Kansas in 2024 was approximately $185.72 billion.
