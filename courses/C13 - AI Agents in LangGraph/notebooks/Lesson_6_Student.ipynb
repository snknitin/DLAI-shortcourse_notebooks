# %% [markdown]
# # Lesson 6: Essay Writer

# %%
from dotenv import load_dotenv

_ = load_dotenv()

# %%
from langgraph.graph import StateGraph, START, END
from typing import Annotated
from typing_extensions import TypedDict
from langgraph.checkpoint.memory import MemorySaver
from langchain_core.messages import SystemMessage, HumanMessage, AIMessage

memory = MemorySaver()

# %%
class AgentState(TypedDict):
    task: str
    plan: str
    draft: str
    critique: str
    content: list[str]
    revision_number: int
    max_revisions: int

# %%
from langchain_openai import ChatOpenAI
model = ChatOpenAI(model="gpt-4o", temperature=0)

# %%
PLAN_PROMPT = """You are an expert writer tasked with writing a high level outline of an essay. \
Write such an outline for the user provided topic. Give an outline of the essay along with any relevant notes \
or instructions for the sections."""

# %%
WRITER_PROMPT = """You are an essay assistant tasked with writing excellent 5-paragraph essays.\
Generate the best essay possible for the user's request and the initial outline. \
If the user provides critique, respond with a revised version of your previous attempts. \
Utilize all the information below as needed:

------

{content}"""

# %%
REFLECTION_PROMPT = """You are a teacher grading an essay submission. \
Generate critique and recommendations for the user's submission. \
Provide detailed recommendations, including requests for length, depth, style, etc."""

# %%
RESEARCH_PLAN_PROMPT = """You are a researcher charged with providing information that can \
be used when writing the following essay. Generate a list of search queries that will gather \
any relevant information. Only generate 3 queries max."""

# %%
RESEARCH_CRITIQUE_PROMPT = """You are a researcher charged with providing information that can \
be used when making any requested revisions (as outlined below). \
Generate a list of search queries that will gather any relevant information. Only generate 3 queries max."""

# %%
from pydantic import BaseModel

class Queries(BaseModel):
    queries: list[str]

# %%
from tavily import TavilyClient
import os
tavily = TavilyClient(api_key=os.environ["TAVILY_API_KEY"])

# %%
def plan_node(state: AgentState):
    messages = [
        SystemMessage(content=PLAN_PROMPT),
        HumanMessage(content=state['task'])
    ]
    response = model.invoke(messages)
    return {"plan": response.content}

# %%
def research_plan_node(state: AgentState):
    queries = model.with_structured_output(Queries).invoke([
        SystemMessage(content=RESEARCH_PLAN_PROMPT),
        HumanMessage(content=state['task'])
    ])
    content = state.get('content') or []
    for q in queries.queries:
        response = tavily.search(query=q, max_results=2)
        for r in response['results']:
            content.append(r['content'])
    return {"content": content}

# %%
def generation_node(state: AgentState):
    content = "\n\n".join(state['content'] or [])
    user_message = HumanMessage(
        content=f"{state['task']}\n\nHere is my plan:\n\n{state['plan']}")
    messages = [
        SystemMessage(
            content=WRITER_PROMPT.format(content=content)
        ),
        user_message
        ]
    response = model.invoke(messages)
    return {
        "draft": response.content,
        "revision_number": state.get("revision_number", 1) + 1
    }

# %%
def reflection_node(state: AgentState):
    messages = [
        SystemMessage(content=REFLECTION_PROMPT),
        HumanMessage(content=state['draft'])
    ]
    response = model.invoke(messages)
    return {"critique": response.content}

# %%
def research_critique_node(state: AgentState):
    queries = model.with_structured_output(Queries).invoke([
        SystemMessage(content=RESEARCH_CRITIQUE_PROMPT),
        HumanMessage(content=state['critique'])
    ])
    content = state.get('content') or []
    for q in queries.queries:
        response = tavily.search(query=q, max_results=2)
        for r in response['results']:
            content.append(r['content'])
    return {"content": content}

# %%
def should_continue(state):
    if state["revision_number"] > state["max_revisions"]:
        return END
    return "reflect"

# %%
builder = StateGraph(AgentState)

# %%
builder.add_node("planner", plan_node)
builder.add_node("generate", generation_node)
builder.add_node("reflect", reflection_node)
builder.add_node("research_plan", research_plan_node)
builder.add_node("research_critique", research_critique_node)

# %%
builder.add_edge(START, "planner")

# %%
builder.add_conditional_edges(
    "generate",
    should_continue,
    {END: END, "reflect": "reflect"}
)

# %%
builder.add_edge("planner", "research_plan")
builder.add_edge("research_plan", "generate")

builder.add_edge("reflect", "research_critique")
builder.add_edge("research_critique", "generate")

# %%
graph = builder.compile(checkpointer=memory)

# %%
from IPython.display import Image

Image(graph.get_graph().draw_mermaid_png())

# %%
thread = {"configurable": {"thread_id": "1"}}
for s in graph.stream({
    'task': "what is the difference between langchain and langsmith",
    "max_revisions": 2,
    "revision_number": 1,
}, thread):
    print(s)
# Out:
# {'planner': {'plan': 'Title: Understanding the Differences Between LangChain and LangSmith\n\nI. Introduction\n   A. Brief introduction to the importance of language processing tools in modern technology.\n   B. Introduction to LangChain and LangSmith as prominent tools in the field.\n   C. Purpose of the essay: To explore and differentiate between LangChain and LangSmith.\n\nII. Overview of LangChain\n   A. Definition and primary purpose of LangChain.\n   B. Key features and functionalities.\n      1. Language processing capabilities.\n      2. Integration with other technologies.\n      3. User interface and ease of use.\n   C. Typical use cases and applications.\n   D. Advantages and limitations.\n\nIII. Overview of LangSmith\n   A. Definition and primary purpose of LangSmith.\n   B. Key features and functionalities.\n      1. Language processing capabilities.\n      2. Integration with other technologies.\n      3. User interface and ease of use.\n   C. Typical use cases and applications.\n   D. Advantages and limitations.\n\nIV. Comparative Analysis\n   A. Feature Comparison\n      1. Language processing capabilities.\n      2. Integration and compatibility with other systems.\n      3. User experience and interface design.\n   B. Performance and Efficiency\n      1. Speed and accuracy of processing.\n      2. Resource consumption and scalability.\n   C. Use Case Suitability\n      1. Best scenarios for using LangChain.\n      2. Best scenarios for using LangSmith.\n   D. Community and Support\n      1. Availability of resources and documentation.\n      2. Community engagement and support networks.\n\nV. Conclusion\n   A. Summary of key differences between LangChain and LangSmith.\n   B. Recommendations for choosing between the two based on specific needs and contexts.\n   C. Final thoughts on the future of language processing tools and their impact on technology.\n\nInstructions for Sections:\n- Ensure each section is well-researched and supported by credible sources.\n- Use clear and concise language to explain technical concepts.\n- Include examples where applicable to illustrate points.\n- Maintain an objective tone throughout the essay, focusing on factual comparisons.\n- In the conclusion, provide a balanced view that acknowledges the strengths and weaknesses of both tools.'}}
# {'research_plan': {'content': ['If you’re responsible for ensuring your AI models work in production, or you need to frequently debug and monitor your pipelines, Langsmith is your go-to tool. In short, while **Langchain** excels at managing and scaling model workflows, **Langsmith** is designed for those times when you need deep visibility and control over large, complex AI systems in production. But if you’re managing a **complex AI pipeline** with multiple models that need debugging and orchestrating, Langsmith’s capabilities become essential. However, if you’re dealing with **large-scale production environments** that require deep monitoring, performance tuning, and orchestration across various models and platforms, Langsmith’s more advanced architecture will handle your needs better. If you’re debugging complex AI models or managing large-scale workflows with multiple moving parts, **Langsmith’s advanced debugging and orchestration features** will be indispensable. Choosing between **Langchain** and **Langsmith** boils down to understanding your project’s complexity, scalability needs, and the level of control you want over your AI models.', 'Compare LangChain, LangSmith, and Orq.ai to discover the best LLM development tools for building, deploying, and optimizing scalable AI applications. By offering an integrated solution that supports the entire LLM development lifecycle, Orq.ai enables teams to seamlessly build, deploy, and optimize LLM applications at scale, without needing to juggle multiple specialized tools. By offering an integrated solution that supports the entire LLM development lifecycle, Orq.ai enables teams to seamlessly build, deploy, and optimize LLM applications at scale, without needing to juggle multiple specialized tools. By offering an integrated solution that supports the entire LLM development lifecycle, Orq.ai enables teams to seamlessly build, deploy, and optimize LLM applications at scale, without needing to juggle multiple specialized tools. By offering an integrated solution that supports the entire LLM development lifecycle, Orq.ai enables teams to seamlessly build, deploy, and optimize LLM applications at scale, without needing to juggle multiple specialized tools.', 'If you’re responsible for ensuring your AI models work in production, or you need to frequently debug and monitor your pipelines, Langsmith is your go-to tool. In short, while **Langchain** excels at managing and scaling model workflows, **Langsmith** is designed for those times when you need deep visibility and control over large, complex AI systems in production. But if you’re managing a **complex AI pipeline** with multiple models that need debugging and orchestrating, Langsmith’s capabilities become essential. However, if you’re dealing with **large-scale production environments** that require deep monitoring, performance tuning, and orchestration across various models and platforms, Langsmith’s more advanced architecture will handle your needs better. If you’re debugging complex AI models or managing large-scale workflows with multiple moving parts, **Langsmith’s advanced debugging and orchestration features** will be indispensable. Choosing between **Langchain** and **Langsmith** boils down to understanding your project’s complexity, scalability needs, and the level of control you want over your AI models.', 'LangChain is ideal for early-stage prototyping and small-scale applications, while LangSmith is better suited for large-scale, production-ready applications.', "Enter LangSmith and LangChain, two platforms designed to streamline the development of LLM-powered applications. Anatomist AI, developed by Eric David Smith, is a revolutionary artificial intelligence tool designed to educate and assist users in the field of human anatomy. Explore the capabilities of Azlyn AI, a groundbreaking platform that harnesses the power of artificial intelligence to decode the hidden meanings within your dreams and visions. ### Business ...
# {'generate': {'draft': "Title: Understanding the Differences Between LangChain and LangSmith\n\nI. Introduction\n\nIn the rapidly evolving landscape of artificial intelligence, language processing tools have become indispensable in modern technology. These tools enable developers to create sophisticated applications that can understand and generate human language, thereby enhancing user interaction and automating complex tasks. Among the prominent tools in this field are LangChain and LangSmith, each offering unique capabilities for managing language model workflows. This essay aims to explore and differentiate between LangChain and LangSmith, providing insights into their functionalities, use cases, and suitability for various applications.\n\nII. Overview of LangChain\n\nLangChain is a powerful tool designed primarily for managing and scaling language model workflows. Its primary purpose is to facilitate the design and prototyping of complex language model applications. Key features of LangChain include its robust language processing capabilities, which allow for seamless integration with external tools and APIs. This integration is crucial for developers looking to build comprehensive applications that require interaction with various data sources and services. LangChain's user interface is designed to be intuitive, making it accessible for developers at different skill levels. Typical use cases for LangChain include early-stage prototyping and small-scale applications where flexibility and rapid iteration are essential. However, while LangChain excels in these areas, it may face limitations when scaling to large, production-ready environments.\n\nIII. Overview of LangSmith\n\nLangSmith, on the other hand, is tailored for large-scale, production-ready applications. Its primary purpose is to provide deep visibility and control over complex AI systems in production. LangSmith's key features include advanced debugging and orchestration capabilities, which are indispensable for managing complex AI pipelines with multiple models. It offers rich visualization tools to display language model call traces, aiding developers in understanding and debugging workflows. LangSmith's integration with other technologies is robust, supporting real-world AI application development, including chatbots and interactive systems. The user interface is designed to facilitate monitoring and management, ensuring smooth operation of AI models in production environments. Typical use cases for LangSmith involve large-scale workflows that require extensive monitoring, performance tuning, and orchestration. While LangSmith is highly effective in these scenarios, it may be more complex to set up and manage compared to LangChain.\n\nIV. Comparative Analysis\n\nWhen comparing LangChain and LangSmith, several key differences emerge. In terms of language processing capabilities, LangChain is well-suited for prototyping and small-scale applications, while LangSmith excels in handling complex, large-scale production environments. Regarding integration and compatibility, both tools offer robust solutions, but LangSmith's advanced architecture provides deeper monitoring and orchestration features. User experience and interface design are tailored to their respective purposes, with LangChain focusing on ease of use for rapid development and LangSmith emphasizing control and visibility for production management. Performance and efficiency also differ, with LangSmith offering superior scalability and resource management for large environments. In terms of community and support, both tools have active communities, but LangSmith's focus on production environments may offer more specialized resources and documentation.\n\nV. Conclusion\n\nIn summary, LangChain and LangSmith serve distinct purposes within the realm of language processing tools. LangChain is ideal for early-stage prototyping and small-scale applications, offering flexibility and ease of use. In contrast,  ...
# {'reflect': {'critique': 'Your essay provides a clear and structured comparison between LangChain and LangSmith, highlighting their respective strengths and use cases. However, there are several areas where you can enhance the depth and clarity of your analysis. Here are some detailed recommendations:\n\n1. **Introduction Enhancement**:\n   - **Contextual Background**: Provide a brief background on the importance of language processing tools in AI. This could include a mention of how these tools fit into the broader AI ecosystem and their impact on industries.\n   - **Thesis Statement**: Clearly state the purpose of the essay and what you aim to achieve with the comparison. This will guide the reader on what to expect.\n\n2. **Detailed Feature Analysis**:\n   - **LangChain**: Expand on the specific features of LangChain. For instance, discuss any unique algorithms or technologies it employs, and how these contribute to its strengths in prototyping.\n   - **LangSmith**: Similarly, delve deeper into LangSmith’s advanced features. Explain how its debugging and orchestration capabilities work and why they are beneficial for large-scale applications.\n\n3. **Use Case Examples**:\n   - Provide concrete examples or case studies where LangChain and LangSmith have been successfully implemented. This will help illustrate their practical applications and benefits.\n\n4. **Comparative Analysis**:\n   - **Technical Depth**: Include more technical details in your comparison. Discuss specific scenarios where one tool might outperform the other, and why.\n   - **Performance Metrics**: If available, include any performance metrics or benchmarks that highlight the differences in efficiency and scalability between the two tools.\n\n5. **User Experience**:\n   - Discuss the learning curve associated with each tool. How easy is it for new users to get started? Are there any specific challenges developers face when using these tools?\n\n6. **Community and Support**:\n   - Expand on the community and support aspect. Are there any notable forums, user groups, or resources that are particularly helpful for users of LangChain or LangSmith?\n\n7. **Conclusion**:\n   - Reinforce the key points made in the essay and suggest potential future developments for both tools. Speculate on how they might evolve to meet emerging needs in AI.\n\n8. **Style and Clarity**:\n   - Ensure that your writing is concise and free of jargon unless necessary. Where technical terms are used, provide explanations to ensure clarity for readers who may not be familiar with them.\n\n9. **Length and Depth**:\n   - Consider expanding the essay to include more detailed sections on each tool. This could involve adding subsections under each main heading to explore specific aspects in greater detail.\n\nBy incorporating these recommendations, you can provide a more comprehensive and insightful analysis of LangChain and LangSmith, offering valuable guidance to developers and stakeholders in the AI field.'}}
# {'research_critique': {'content': ['If you’re responsible for ensuring your AI models work in production, or you need to frequently debug and monitor your pipelines, Langsmith is your go-to tool. In short, while **Langchain** excels at managing and scaling model workflows, **Langsmith** is designed for those times when you need deep visibility and control over large, complex AI systems in production. But if you’re managing a **complex AI pipeline** with multiple models that need debugging and orchestrating, Langsmith’s capabilities become essential. However, if you’re dealing with **large-scale production environments** that require deep monitoring, performance tuning, and orchestration across various models and platforms, Langsmith’s more advanced architecture will handle your needs better. If you’re debugging complex AI models or managing large-scale workflows with multiple moving parts, **Langsmith’s advanced debugging and orchestration features** will be indispensable. Choosing between **Langchain** and **Langsmith** boils down to understanding your project’s complexity, scalability needs, and the level of control you want over your AI models.', 'Compare LangChain, LangSmith, and Orq.ai to discover the best LLM development tools for building, deploying, and optimizing scalable AI applications. By offering an integrated solution that supports the entire LLM development lifecycle, Orq.ai enables teams to seamlessly build, deploy, and optimize LLM applications at scale, without needing to juggle multiple specialized tools. By offering an integrated solution that supports the entire LLM development lifecycle, Orq.ai enables teams to seamlessly build, deploy, and optimize LLM applications at scale, without needing to juggle multiple specialized tools. By offering an integrated solution that supports the entire LLM development lifecycle, Orq.ai enables teams to seamlessly build, deploy, and optimize LLM applications at scale, without needing to juggle multiple specialized tools. By offering an integrated solution that supports the entire LLM development lifecycle, Orq.ai enables teams to seamlessly build, deploy, and optimize LLM applications at scale, without needing to juggle multiple specialized tools.', 'If you’re responsible for ensuring your AI models work in production, or you need to frequently debug and monitor your pipelines, Langsmith is your go-to tool. In short, while **Langchain** excels at managing and scaling model workflows, **Langsmith** is designed for those times when you need deep visibility and control over large, complex AI systems in production. But if you’re managing a **complex AI pipeline** with multiple models that need debugging and orchestrating, Langsmith’s capabilities become essential. However, if you’re dealing with **large-scale production environments** that require deep monitoring, performance tuning, and orchestration across various models and platforms, Langsmith’s more advanced architecture will handle your needs better. If you’re debugging complex AI models or managing large-scale workflows with multiple moving parts, **Langsmith’s advanced debugging and orchestration features** will be indispensable. Choosing between **Langchain** and **Langsmith** boils down to understanding your project’s complexity, scalability needs, and the level of control you want over your AI models.', 'LangChain is ideal for early-stage prototyping and small-scale applications, while LangSmith is better suited for large-scale, production-ready applications.', "Enter LangSmith and LangChain, two platforms designed to streamline the development of LLM-powered applications. Anatomist AI, developed by Eric David Smith, is a revolutionary artificial intelligence tool designed to educate and assist users in the field of human anatomy. Explore the capabilities of Azlyn AI, a groundbreaking platform that harnesses the power of artificial intelligence to decode the hidden meanings within your dreams and visions. ### Busi ...
# {'generate': {'draft': "Title: Understanding the Differences Between LangChain and LangSmith\n\nI. Introduction\n\nIn the rapidly evolving landscape of artificial intelligence, language processing tools have become indispensable in developing sophisticated applications. These tools enable developers to harness the power of large language models (LLMs) to create intelligent systems capable of understanding and generating human-like text. Among the prominent tools in this domain are LangChain and LangSmith, each offering unique capabilities tailored to different stages of AI application development. This essay aims to explore and differentiate between LangChain and LangSmith, providing insights into their functionalities, use cases, and suitability for various projects.\n\nII. Overview of LangChain\n\nLangChain is a framework designed to facilitate the development of applications powered by large language models. Its primary purpose is to streamline the creation of complex language model workflows, making it an ideal choice for early-stage prototyping and small-scale applications. Key features of LangChain include its modular design, which allows for seamless integration with external tools and APIs, and its ability to manage complex task chains and context management. LangChain's user-friendly interface and flexibility make it accessible to developers looking to experiment with LLMs. Typical use cases for LangChain include designing chatbots, personal assistants, and other interactive systems. However, its limitations lie in its scalability and lack of advanced debugging tools, which may pose challenges in large-scale production environments.\n\nIII. Overview of LangSmith\n\nLangSmith, on the other hand, is a platform focused on the deployment, debugging, and monitoring of AI applications in production. It is designed for scenarios where deep visibility and control over complex AI systems are required. LangSmith offers advanced debugging and orchestration features, making it indispensable for managing large-scale workflows with multiple moving parts. Its integration capabilities extend across various models and platforms, providing robust tools for performance tuning and monitoring. LangSmith's rich visualization tools and centralized debugging features cater to developers who need to ensure the reliability and efficiency of their AI models in production. While LangSmith excels in production environments, its complexity and resource requirements may not be suitable for early-stage development or smaller projects.\n\nIV. Comparative Analysis\n\nWhen comparing LangChain and LangSmith, several key differences emerge. In terms of language processing capabilities, LangChain focuses on building and managing workflows, while LangSmith emphasizes debugging and monitoring. LangChain's integration with external tools is straightforward, whereas LangSmith offers more advanced orchestration across diverse systems. User experience also varies, with LangChain providing a simpler interface for prototyping, and LangSmith offering detailed visualization tools for production management. Performance-wise, LangSmith is optimized for large-scale environments, offering superior monitoring and tuning capabilities. In terms of use case suitability, LangChain is best for prototyping and small-scale applications, while LangSmith is ideal for production-ready, large-scale deployments. Community support for both tools is robust, with LangChain benefiting from a strong developer community and LangSmith offering comprehensive documentation and support networks.\n\nV. Conclusion\n\nIn summary, LangChain and LangSmith serve distinct purposes within the AI development lifecycle. LangChain is well-suited for early-stage development and prototyping, offering flexibility and ease of use. In contrast, LangSmith provides the necessary tools for deploying and managing AI applications in production, with advanced debugging and monitoring features. When choosing betwe ...

# %% [markdown]
# ## Essay Writer Interface

# %%
import warnings
warnings.filterwarnings("ignore")

from helper import ewriter, writer_gui

# %%
MultiAgent = ewriter()
app = writer_gui(MultiAgent.graph)
app.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7861
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7861/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Traceback (most recent call last):
#   File "e:\GIT_ROOT\Learning\DLAI-shortcourse_notebooks\.venv\Lib\site-packages\gradio\queueing.py", line 785, in process_events
#     response = await route_utils.call_process_api(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\GIT_ROOT\Learning\DLAI-shortcourse_notebooks\.venv\Lib\site-packages\gradio\route_utils.py", line 358, in call_process_api
#     output = await app.get_blocks().process_api(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\GIT_ROOT\Learning\DLAI-shortcourse_notebooks\.venv\Lib\site-packages\gradio\blocks.py", line 2172, in process_api
#     result = await self.call_function(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\GIT_ROOT\Learning\DLAI-shortcourse_notebooks\.venv\Lib\site-packages\gradio\blocks.py", line 1634, in call_function
#     prediction = await anyio.to_thread.run_sync(  # type: ignore
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\GIT_ROOT\Learning\DLAI-shortcourse_notebooks\.venv\Lib\site-packages\anyio\to_thread.py", line 63, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\GIT_ROOT\Learning\DLAI-shortcourse_notebooks\.venv\Lib\site-packages\anyio\_backends\_asyncio.py", line 2518, in run_sync_in_worker_thread
#     return await future
#            ^^^^^^^^^^^^
#   File "e:\GIT_ROOT\Learning\DLAI-shortcourse_notebooks\.venv\Lib\site-packages\anyio\_backends\_asyncio.py", line 1002, in run
#     result = context.run(func, *args)
#              ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "e:\GIT_ROOT\Learning\DLAI-shortcourse_notebooks\.venv\Lib\site-packages\gradio\utils.py", line 1059, in wrapper
#     response = f(*args, **kwargs)
#                ^^^^^^^^^^^^^^^^^^
#   File "e:\GIT_ROOT\Learning\DLAI-shortcourse_notebooks\courses\C13 - AI Agents in LangGraph\notebooks\helper.py", line 307, in updt_disp
#     s_checkpoint_id = state.config['configurable']['checkpoint_id']
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyError: 'thread_ts'
