# %% [markdown]
# # Lesson 5: Human in the Loop

# %% [markdown]
# Note: This notebook is running in a later version of langgraph that it was filmed with. The later version has a couple of key additions:
# - Additional state information is stored to memory and displayed when using `get_state()` or `get_state_history()`.
# - State is additionally stored every state transition while previously it was stored at an interrupt or at the end.
# These change the command output slightly, but are a useful addtion to the information available.

# %%
from dotenv import load_dotenv

_ = load_dotenv()

# %%
from langgraph.graph import StateGraph, START, END
from langgraph.graph.message import add_messages
from typing import Annotated
from typing_extensions import TypedDict
from langchain_core.messages import AnyMessage, SystemMessage, HumanMessage, ToolMessage
from langchain_openai import ChatOpenAI
from langchain_tavily import TavilySearch
from langgraph.checkpoint.memory import MemorySaver

memory = MemorySaver()

# %%
"""
The `add_messages` reducer from langgraph handles message merging:
it replaces messages with the same `id` and appends new ones otherwise.
This replaces the need for a custom reduce_messages function.
"""

class AgentState(TypedDict):
    messages: Annotated[list[AnyMessage], add_messages]

# %%
tool = TavilySearch(max_results=2)

# %% [markdown]
# ## Manual human approval

# %%
class Agent:
    def __init__(self, model, tools, system="", checkpointer=None):
        self.system = system
        graph = StateGraph(AgentState)
        graph.add_node("llm", self.call_openai)
        graph.add_node("action", self.take_action)
        graph.add_conditional_edges("llm", self.exists_action, {True: "action", False: END})
        graph.add_edge("action", "llm")
        graph.add_edge(START, "llm")
        self.graph = graph.compile(
            checkpointer=checkpointer,
            interrupt_before=["action"]
        )
        self.tools = {t.name: t for t in tools}
        self.model = model.bind_tools(tools)

    def call_openai(self, state: AgentState):
        messages = state['messages']
        if self.system:
            messages = [SystemMessage(content=self.system)] + messages
        message = self.model.invoke(messages)
        return {'messages': [message]}

    def exists_action(self, state: AgentState):
        print(state)
        result = state['messages'][-1]
        return len(result.tool_calls) > 0

    def take_action(self, state: AgentState):
        tool_calls = state['messages'][-1].tool_calls
        results = []
        for t in tool_calls:
            print(f"Calling: {t}")
            result = self.tools[t['name']].invoke(t['args'])
            results.append(ToolMessage(tool_call_id=t['id'], name=t['name'], content=str(result)))
        print("Back to the model!")
        return {'messages': results}

# %%
prompt = """You are a smart research assistant. Use the search engine to look up information. \
You are allowed to make multiple calls (either together or in sequence). \
Only look up information when you are sure of what you want. \
If you need to look up some information before asking a follow up question, you are allowed to do that!
"""
model = ChatOpenAI(model="gpt-4o")
abot = Agent(model, [tool], system=prompt, checkpointer=memory)

# %%
messages = [HumanMessage(content="Whats the weather in SF?")]
thread = {"configurable": {"thread_id": "1"}}
for event in abot.graph.stream({"messages": messages}, thread):
    for v in event.values():
        print(v)
# Out:
# {'messages': [HumanMessage(content='Whats the weather in SF?', additional_kwargs={}, response_metadata={}, id='f7b9eec5-fa91-4de0-a917-6cef879477b0'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 1258, 'total_tokens': 1281, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1152}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_2ca5b70601', 'id': 'chatcmpl-DSfJ0M1ucE1BGA7Q5534yX7IiEZnQ', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019d716b-0210-7750-9f46-087c6525b81a-0', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'San Francisco weather', 'search_depth': 'fast'}, 'id': 'call_Ar5k1GBcvYUlIlr1JyABsi47', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1258, 'output_tokens': 23, 'total_tokens': 1281, 'input_token_details': {'audio': 0, 'cache_read': 1152}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
# {'messages': [AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 1258, 'total_tokens': 1281, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1152}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_2ca5b70601', 'id': 'chatcmpl-DSfJ0M1ucE1BGA7Q5534yX7IiEZnQ', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019d716b-0210-7750-9f46-087c6525b81a-0', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'San Francisco weather', 'search_depth': 'fast'}, 'id': 'call_Ar5k1GBcvYUlIlr1JyABsi47', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1258, 'output_tokens': 23, 'total_tokens': 1281, 'input_token_details': {'audio': 0, 'cache_read': 1152}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
# ()

# %%
abot.graph.get_state(thread)
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in SF?', additional_kwargs={}, response_metadata={}, id='f7b9eec5-fa91-4de0-a917-6cef879477b0'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 1258, 'total_tokens': 1281, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1152}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_2ca5b70601', 'id': 'chatcmpl-DSfJ0M1ucE1BGA7Q5534yX7IiEZnQ', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019d716b-0210-7750-9f46-087c6525b81a-0', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'San Francisco weather', 'search_depth': 'fast'}, 'id': 'call_Ar5k1GBcvYUlIlr1JyABsi47', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1258, 'output_tokens': 23, 'total_tokens': 1281, 'input_token_details': {'audio': 0, 'cache_read': 1152}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}, next=('action',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f133f07-8397-6aa5-8001-3abadb4aa3b4'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-04-09T08:45:32.739651+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f133f07-7817-6283-8000-8cd456f2132d'}}, tasks=(PregelTask(id='b86f5be8-0123-5c68-d320-a4fb45c090ad', name='action', path=('__pregel_pull', 'action'), error=None, interrupts=(), state=None, result=None),), interrupts=())

# %%
abot.graph.get_state(thread).next
# Out:
# ('action',)

# %% [markdown]
# ### continue after interrupt

# %%
for event in abot.graph.stream(None, thread):
    for v in event.values():
        print(v)
# Out:
# Calling: {'name': 'tavily_search', 'args': {'query': 'San Francisco weather', 'search_depth': 'fast'}, 'id': 'call_Ar5k1GBcvYUlIlr1JyABsi47', 'type': 'tool_call'}
# Back to the model!
# {'messages': [ToolMessage(content='{\'query\': \'San Francisco weather\', \'response_time\': 0.26, \'follow_up_questions\': None, \'answer\': None, \'images\': [], \'results\': [{\'url\': \'https://www.pinterest.ca/ideas/san-francisco-weather/902591070251\', \'title\': \'San Francisco Weather\', \'content\': "San Francisco Weather [...] Weather Map, San Francisco March Outfit, San Francisco Spring Break, Winter In San Francisco, San Francisco Weather, San Francisco Climate Map. a large wave is coming in from the ocean behind some buildings and houses on the beach. the golden gate bridge in san francisco, california on a cloudy day with blue flowers. a woman walking across a bridge with the caption what to do when it\'s pouring rain in san francisco. an image of the weather in san francisco, california with different times and [...] Title: San Francisco Weather", \'score\': 0.68090034, \'raw_content\': None}, {\'url\': \'https://www.pinterest.com/ideas/san-francisco-weather/902591070251\', \'title\': \'San Francisco Weather\', \'content\': "San Francisco Weather [...] Weather Map, San Francisco March Outfit, San Francisco Spring Break, Winter In San Francisco, San Francisco Weather, San Francisco Climate Map. a large wave is coming in from the ocean behind some buildings and houses on the beach. the golden gate bridge in san francisco, california on a cloudy day with blue flowers. a woman walking across a bridge with the caption what to do when it\'s pouring rain in san francisco. an image of the weather in san francisco, california with different times and [...] Title: San Francisco Weather", \'score\': 0.68090034, \'raw_content\': None}], \'request_id\': \'ed3664de-accf-4124-bb4e-01e637cfe564\'}', name='tavily_search', id='8e495e8b-7ed4-418a-bccc-ca45decd2eba', tool_call_id='call_Ar5k1GBcvYUlIlr1JyABsi47')]}
# {'messages': [HumanMessage(content='Whats the weather in SF?', additional_kwargs={}, response_metadata={}, id='f7b9eec5-fa91-4de0-a917-6cef879477b0'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 1258, 'total_tokens': 1281, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1152}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_2ca5b70601', 'id': 'chatcmpl-DSfJ0M1ucE1BGA7Q5534yX7IiEZnQ', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019d716b-0210-7750-9f46-087c6525b81a-0', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'San Francisco weather', 'search_depth': 'fast'}, 'id': 'call_Ar5k1GBcvYUlIlr1JyABsi47', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1258, 'output_tokens': 23, 'total_tokens': 1281, 'input_token_details': {'audio': 0, 'cache_read': 1152}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='{\'query\': \'San Francisco weather\', \'response_time\': 0.26, \'follow_up_questions\': None, \'answer\': None, \'images\': [], \'results\': [{\'url\': \'https://www.pinterest.ca/ideas/san-francisco-weather/902591070251\', \'title\': \'San Francisco Weather\', \'content\': "San Francisco Weather [...] Weather Map, San Francisco March Outfit, San Francisco Spring Break, Winter In San Francisco, San Francisco Weather, San Francisco Climate Map. a large wave is coming in from the ocean behind some buildings and houses on the beach. the golden gate bridge in san francisco, california on a cloudy day with blue flowers. a woman walking across a bridge with the caption what to do when it\'s pouring rain in san francisco. an image of the weather in san francisco, california with different times and [...] Title: San Francisco Weather", \'score\': 0.68090034, \'raw_content\': None}, {\'url\': \'https://www.pinterest.com/ideas/san-francisco-weather/902591070251\', \'title\': \'San Francisco Weather\', \'content\': "San Francisco Weather [...] Weather Map, San Francisco March Outfit, San Francisco Spring Break, Winter In San Francisco, San Francisco Weather, San Francisco Climate Map. a large wave is coming in from the ocean behind some buildings and houses on the beach. the golden gate bridge in san francisco, california on a cloudy day with blue flowers. a woman walking across a bridge with the caption what to do when it\'s pouring rain in san francisco. an image of the weather in san francisco, california with different times and [...] Title: San Francisco Weather", \'score\': 0.68090034, \'raw_content\': None}], \'request_id\': \'ed3664de-accf-4124-bb4e-01e637cfe564\'}', name='tavily_search', id='8e495e8b-7ed4-418a-bccc-ca45decd2eba', tool_call_id='call_Ar5k1GBcvYUlIlr1JyABsi47'), AIMessage(content="I couldn't retrieve the current weather for San Francisco. You can check a weather website or app for the most up-to-date information.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 27, 'prompt_tokens': 1678, 'total_tokens': 1705, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1280}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_2ca5b70601', 'id': 'chatcmpl-DSfJ2wnsAEWaJT9fhZDjnfEP7PTIG', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d716b-0c0a-7f10-ae6b-b115b92c49ea-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1678, 'output_tokens': 27, 'total_tokens': 1705, 'input_token_details': {'audio': 0, 'cache_read': 1280}, 'output_token_details': {'au ...
# {'messages': [AIMessage(content="I couldn't retrieve the current weather for San Francisco. You can check a weather website or app for the most up-to-date information.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 27, 'prompt_tokens': 1678, 'total_tokens': 1705, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1280}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_2ca5b70601', 'id': 'chatcmpl-DSfJ2wnsAEWaJT9fhZDjnfEP7PTIG', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d716b-0c0a-7f10-ae6b-b115b92c49ea-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1678, 'output_tokens': 27, 'total_tokens': 1705, 'input_token_details': {'audio': 0, 'cache_read': 1280}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}

# %%
abot.graph.get_state(thread)
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in SF?', additional_kwargs={}, response_metadata={}, id='f7b9eec5-fa91-4de0-a917-6cef879477b0'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 1258, 'total_tokens': 1281, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1152}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_2ca5b70601', 'id': 'chatcmpl-DSfJ0M1ucE1BGA7Q5534yX7IiEZnQ', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019d716b-0210-7750-9f46-087c6525b81a-0', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'San Francisco weather', 'search_depth': 'fast'}, 'id': 'call_Ar5k1GBcvYUlIlr1JyABsi47', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1258, 'output_tokens': 23, 'total_tokens': 1281, 'input_token_details': {'audio': 0, 'cache_read': 1152}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='{\'query\': \'San Francisco weather\', \'response_time\': 0.26, \'follow_up_questions\': None, \'answer\': None, \'images\': [], \'results\': [{\'url\': \'https://www.pinterest.ca/ideas/san-francisco-weather/902591070251\', \'title\': \'San Francisco Weather\', \'content\': "San Francisco Weather [...] Weather Map, San Francisco March Outfit, San Francisco Spring Break, Winter In San Francisco, San Francisco Weather, San Francisco Climate Map. a large wave is coming in from the ocean behind some buildings and houses on the beach. the golden gate bridge in san francisco, california on a cloudy day with blue flowers. a woman walking across a bridge with the caption what to do when it\'s pouring rain in san francisco. an image of the weather in san francisco, california with different times and [...] Title: San Francisco Weather", \'score\': 0.68090034, \'raw_content\': None}, {\'url\': \'https://www.pinterest.com/ideas/san-francisco-weather/902591070251\', \'title\': \'San Francisco Weather\', \'content\': "San Francisco Weather [...] Weather Map, San Francisco March Outfit, San Francisco Spring Break, Winter In San Francisco, San Francisco Weather, San Francisco Climate Map. a large wave is coming in from the ocean behind some buildings and houses on the beach. the golden gate bridge in san francisco, california on a cloudy day with blue flowers. a woman walking across a bridge with the caption what to do when it\'s pouring rain in san francisco. an image of the weather in san francisco, california with different times and [...] Title: San Francisco Weather", \'score\': 0.68090034, \'raw_content\': None}], \'request_id\': \'ed3664de-accf-4124-bb4e-01e637cfe564\'}', name='tavily_search', id='8e495e8b-7ed4-418a-bccc-ca45decd2eba', tool_call_id='call_Ar5k1GBcvYUlIlr1JyABsi47'), AIMessage(content="I couldn't retrieve the current weather for San Francisco. You can check a weather website or app for the most up-to-date information.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 27, 'prompt_tokens': 1678, 'total_tokens': 1705, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1280}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_2ca5b70601', 'id': 'chatcmpl-DSfJ2wnsAEWaJT9fhZDjnfEP7PTIG', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d716b-0c0a-7f10-ae6b-b115b92c49ea-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1678, 'output_tokens': 27, 'total_tokens': 1705, 'input_token_details': {'audio': 0, 'cache_read': 1280}, 'output ...

# %%
abot.graph.get_state(thread).next
# Out:
# ()

# %%
messages = [HumanMessage("Whats the weather in LA?")]
thread = {"configurable": {"thread_id": "2"}}
for event in abot.graph.stream({"messages": messages}, thread):
    for v in event.values():
        print(v)
while abot.graph.get_state(thread).next:
    print("\n", abot.graph.get_state(thread),"\n")
    _input = input("proceed?")
    if _input != "y":
        print("aborting")
        break
    for event in abot.graph.stream(None, thread):
        for v in event.values():
            print(v)
# Out:
# {'messages': [HumanMessage(content='Whats the weather in LA?', additional_kwargs={}, response_metadata={}, id='2c1bc928-96ca-48f2-b7da-beb19f5867c9'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 1258, 'total_tokens': 1281, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1152}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_9860921a69', 'id': 'chatcmpl-DSfJ45Q1iH3BMTaz94XgcNyhIOuyX', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019d716b-107e-7262-9c20-d7033a614962-0', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'Los Angeles weather', 'search_depth': 'fast'}, 'id': 'call_Wo4uh6gbLzrQmVcyG66SZq50', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1258, 'output_tokens': 23, 'total_tokens': 1281, 'input_token_details': {'audio': 0, 'cache_read': 1152}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
# {'messages': [AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 1258, 'total_tokens': 1281, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1152}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_9860921a69', 'id': 'chatcmpl-DSfJ45Q1iH3BMTaz94XgcNyhIOuyX', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019d716b-107e-7262-9c20-d7033a614962-0', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'Los Angeles weather', 'search_depth': 'fast'}, 'id': 'call_Wo4uh6gbLzrQmVcyG66SZq50', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1258, 'output_tokens': 23, 'total_tokens': 1281, 'input_token_details': {'audio': 0, 'cache_read': 1152}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
# ()
#
#  StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in LA?', additional_kwargs={}, response_metadata={}, id='2c1bc928-96ca-48f2-b7da-beb19f5867c9'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 1258, 'total_tokens': 1281, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1152}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_9860921a69', 'id': 'chatcmpl-DSfJ45Q1iH3BMTaz94XgcNyhIOuyX', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019d716b-107e-7262-9c20-d7033a614962-0', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'Los Angeles weather', 'search_depth': 'fast'}, 'id': 'call_Wo4uh6gbLzrQmVcyG66SZq50', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1258, 'output_tokens': 23, 'total_tokens': 1281, 'input_token_details': {'audio': 0, 'cache_read': 1152}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}, next=('action',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f133f07-afd7-60cb-8001-29a6085af3c1'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-04-09T08:45:37.379348+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f133f07-9b54-6ca4-8000-7090d888d656'}}, tasks=(PregelTask(id='dc9ffd60-232f-88fa-1a92-809a85f770b9', name='action', path=('__pregel_pull', 'action'), error=None, interrupts=(), state=None, result=None),), interrupts=())
#
# Calling: {'name': 'tavily_search', 'args': {'query': 'Los Angeles weather', 'search_depth': 'fast'}, 'id': 'call_Wo4uh6gbLzrQmVcyG66SZq50', 'type': 'tool_call'}
# Back to the model!
# {'messages': [ToolMessage(content='{\'query\': \'Los Angeles weather\', \'follow_up_questions\': None, \'answer\': None, \'images\': [], \'results\': [{\'url\': \'https://www.spreaker.com/podcast/weather-in-los-angeles--5943299\', \'title\': \'Weather in Los Angeles\', \'content\': \'#### Today\\\'s Weather in Los Angeles 03/27/26 Sunny Skies and 80 Degrees with Perfect Weekend Ahead. I\\\'m absolutely pumped to talk about what\\\'s happening in Los Angeles today, and let me tell you, it\\\'s going to be a pretty fantastic stretch of weather. We\\\'re expecting clearing skies, a high near eighty-six degrees, and light winds. #### Today\\\'s Weather in Los Angeles 03/26/26 Sunny Skies Ahead With Highs Near 83 Degrees. I\\\'m Dustin Breeze, your artificially intelligent meteorologist, and I [...] Today\\\'s Weather in Los Angeles 03/18/26 Extreme Heat Warning Wednesday Through Friday with Highs Near 98 Degrees. Wednesday we\\\'re looking at sunny skies with that high near 95 Fahrenheit with light and variable winds becoming southwest five to ten miles per hour in the afternoon. [...] and I process weather data faster than you can say "partly cloudy." Let\\\'s dive into today\\\'s forecast for Los Angeles, where things are about to get absolutely gorgeous! #### Today\\\'s Weather in Los Angeles 03/25/26 Patchy Morning Fog Clearing to Sunny Skies with Highs Near 79 Degrees. Friday is going to be the crown jewel with sunny skies and a high near eighty-eight degrees Fahrenheit. #### Today\\\'s Weather in Los Angeles 03/24/26 Sunny Skies and Seventies with High Pressure Dominating. ####\', \'score\': 0.99701905, \'raw_content\': None}, {\'url\': \'https://www.tripsavvy.com/los-angeles-weather-1586906\', \'title\': \'The Weather and Climate in Los Angeles\', \'content\': "Summers in L.A. are warm and mostly dry. While temperatures might seem low—July averages just 73 degrees Fahrenheit (23 degrees Celsius)—this can vary significantly depending on where you are in the city.2 Locations near the ocean can be 10 or 20 degrees cooler than inland temperatures. [...] Winters can range from cool to warm and are usually the rainiest of L.A.\'s seasons. Temperatures rarely drop below 40 degrees Fahrenheit (4 degrees Celsius), but a frost isn\'t completely unheard of, especially further inland.\\n\\nSanta Ana winds can also blow in during the winter. This phenomenon causes a significant increase in temperature, sometimes spiking temperatures as high as 95 degrees Fahrenheit (35 degrees Celsius). [...] | October | 69 F | 0.6 in | 12 hours |\\n| November | 63 F | 0.8 in | 11 hours |\\n| December | 58 F | 2.3 in | 10 hours |", \'score\': 0.9966756, \'raw_content\': None}], \'response_time\': 0.16, \'request_id\': \'498db7f3-e627-496d-8b57-7b95ce18634a\'}', name='tavily_search', id='714ead23-1e8f-453a-9a53-7ed5ffb0225f', tool_call_id='call_Wo4uh6gbLzrQmVcyG66SZq50')]}
# {'messages': [HumanMessage(content='Whats the weather in LA?', additional_kwargs={}, response_metadata={}, id='2c1bc928-96ca-48f2-b7da-beb19f5867c9'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 1258, 'total_tokens': 1281, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1152}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_9860921a69', 'id': 'chatcmpl-DSfJ45Q1iH3BMTaz94XgcNyhIOuyX', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019d716b-107e-7262-9c20-d7033a614962-0', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'Los Angeles weather', 'search_depth': 'fast'}, 'id': 'call_Wo4uh6gbLzrQmVcyG66SZq50', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1258, 'output_tokens': 23, 'total_tokens': 1281, 'input_token_details': {'audio': 0, 'cache_read': 1152}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='{\'query\': \'Los Angeles weather\', \'follow_up_questions\': None, \'answer\': None, \'images\': [], \'results\': [{\'url\': \'https://www.spreaker.com/podcast/weather-in-los-angeles--5943299\', \'title\': \'Weather in Los Angeles\', \'content\': \'#### Today\\\'s Weather in Los Angeles 03/27/26 Sunny Skies and 80 Degrees with Perfect Weekend Ahead. I\\\'m absolutely pumped to talk about what\\\'s happening in Los Angeles today, and let me tell you, it\\\'s going to be a pretty fantastic stretch of weather. We\\\'re expecting clearing skies, a high near eighty-six degrees, and light winds. #### Today\\\'s Weather in Los Angeles 03/26/26 Sunny Skies Ahead With Highs Near 83 Degrees. I\\\'m Dustin Breeze, your artificially intelligent meteorologist, and I [...] Today\\\'s Weather in Los Angeles 03/18/26 Extreme Heat Warning Wednesday Through Friday with Highs Near 98 Degrees. Wednesday we\\\'re looking at sunny skies with that high near 95 Fahrenheit with light and variable winds becoming southwest five to ten miles per hour in the afternoon. [...] and I process weather data faster than you can say "partly cloudy." Let\\\'s dive into today\\\'s forecast for Los Angeles, where things are about to get absolutely gorgeous! #### Today\\\'s Weather in Los Angeles 03/25/26 Patchy Morning Fog Clearing to Sunny Skies with Highs Near 79 Degrees. Friday is going to be the crown jewel with sunny skies and a high near eighty-eight degrees Fahrenheit. #### Today\\\'s Weather in Los Angeles 03/24/26 Sunny Skies and Seventies with High Pressure Dominating. ####\', \'score\': 0.99701905, \'raw_content\': None}, {\'url\': \'https://www.tripsavvy.com/los-angeles-weather-1586906\', \'title\': \'The Weather and Climate in Los Angeles\', \'content\': "Summers in L.A. are warm and mostly dry. While temperatures might seem low—July averages just 73 degrees Fahrenheit (23 degrees Celsius)—this can vary significantly depending on where you are in the city.2 Locations near the ocean can be 10 or 20 degrees cooler than inland temperatures. [...] Winters can range from cool to warm and are usually the rainiest of L.A.\'s seasons. Temperatures rarely drop below 40 degrees Fahrenheit (4 degrees Celsius), but a frost isn\'t completely unheard of, especially further inland.\\n\\nSanta Ana winds can also blow in during the winter. This phenomenon causes a significant increase in temperature, sometimes spiking temperatures as high as 95 degrees Fahrenheit (35 degrees Celsius). [...] | October | 69 F | 0.6 in | 12 hours |\\n| November | 63 F | 0.8 in | 11 hours |\\n| December | 58 F | 2.3 in | 10 hours |", \'score\': 0.9966756, \'raw_content\': None}], \'response_time\': 0.16, \'request_id\': \'498db7f3-e627-496d-8b57-7b95ce18634a\'}', name='tavily_search', id='714ead23-1e8f-45 ...
# {'messages': [AIMessage(content="Today's weather in Los Angeles features clearing skies with a high near 86 degrees Fahrenheit and light winds. It's expected to be a fantastic stretch of weather, with sunny conditions perfect for outdoor activities.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 39, 'prompt_tokens': 1960, 'total_tokens': 1999, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_2ca5b70601', 'id': 'chatcmpl-DSfJ9o2WWVoNzSZM7zIg4ZwpGNR6s', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d716b-277a-7d41-8c12-2f1972e55071-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1960, 'output_tokens': 39, 'total_tokens': 1999, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}

# %% [markdown]
# ## Modify State
# Run until the interrupt and then modify the state.

# %%
messages = [HumanMessage("Whats the weather in LA?")]
thread = {"configurable": {"thread_id": "3"}}
for event in abot.graph.stream({"messages": messages}, thread):
    for v in event.values():
        print(v)
# Out:
# {'messages': [HumanMessage(content='Whats the weather in LA?', additional_kwargs={}, response_metadata={}, id='c06c33ee-21be-4ee0-bac4-9780aec6bc08'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 24, 'prompt_tokens': 1258, 'total_tokens': 1282, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_2ca5b70601', 'id': 'chatcmpl-DSfJAKvM6BtudLjFtdhWvPJmL6onl', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019d716b-2bec-7672-80b8-1f9b5afdfdfa-0', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'current weather in Los Angeles', 'topic': 'news'}, 'id': 'call_fzTSijP4ZHkAUDFoR6AMhwMh', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1258, 'output_tokens': 24, 'total_tokens': 1282, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
# {'messages': [AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 24, 'prompt_tokens': 1258, 'total_tokens': 1282, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_2ca5b70601', 'id': 'chatcmpl-DSfJAKvM6BtudLjFtdhWvPJmL6onl', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019d716b-2bec-7672-80b8-1f9b5afdfdfa-0', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'current weather in Los Angeles', 'topic': 'news'}, 'id': 'call_fzTSijP4ZHkAUDFoR6AMhwMh', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1258, 'output_tokens': 24, 'total_tokens': 1282, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
# ()

# %%
abot.graph.get_state(thread)
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in LA?', additional_kwargs={}, response_metadata={}, id='c06c33ee-21be-4ee0-bac4-9780aec6bc08'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 24, 'prompt_tokens': 1258, 'total_tokens': 1282, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_2ca5b70601', 'id': 'chatcmpl-DSfJAKvM6BtudLjFtdhWvPJmL6onl', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019d716b-2bec-7672-80b8-1f9b5afdfdfa-0', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'current weather in Los Angeles', 'topic': 'news'}, 'id': 'call_fzTSijP4ZHkAUDFoR6AMhwMh', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1258, 'output_tokens': 24, 'total_tokens': 1282, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}, next=('action',), config={'configurable': {'thread_id': '3', 'checkpoint_ns': '', 'checkpoint_id': '1f133f07-e6d1-6fe0-8001-1d5dd54aebc1'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-04-09T08:45:43.144444+00:00', parent_config={'configurable': {'thread_id': '3', 'checkpoint_ns': '', 'checkpoint_id': '1f133f07-de4c-6fd8-8000-d01c222cc9a4'}}, tasks=(PregelTask(id='a9de5d5d-490e-3a38-73d5-927c000ed692', name='action', path=('__pregel_pull', 'action'), error=None, interrupts=(), state=None, result=None),), interrupts=())

# %%
current_values = abot.graph.get_state(thread)

# %%
current_values.values['messages'][-1]
# Out:
# AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 24, 'prompt_tokens': 1258, 'total_tokens': 1282, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_2ca5b70601', 'id': 'chatcmpl-DSfJAKvM6BtudLjFtdhWvPJmL6onl', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019d716b-2bec-7672-80b8-1f9b5afdfdfa-0', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'current weather in Los Angeles', 'topic': 'news'}, 'id': 'call_fzTSijP4ZHkAUDFoR6AMhwMh', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1258, 'output_tokens': 24, 'total_tokens': 1282, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
current_values.values['messages'][-1].tool_calls
# Out:
# [{'name': 'tavily_search',
#   'args': {'query': 'current weather in Los Angeles', 'topic': 'news'},
#   'id': 'call_fzTSijP4ZHkAUDFoR6AMhwMh',
#   'type': 'tool_call'}]

# %%
_id = current_values.values['messages'][-1].tool_calls[0]['id']
current_values.values['messages'][-1].tool_calls = [
    {'name': 'tavily_search',
  'args': {'query': 'current weather in Louisiana'},
  'id': _id}
]

# %%
abot.graph.update_state(thread, current_values.values)
# Out:
# {'messages': [HumanMessage(content='Whats the weather in LA?', additional_kwargs={}, response_metadata={}, id='c06c33ee-21be-4ee0-bac4-9780aec6bc08'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 24, 'prompt_tokens': 1258, 'total_tokens': 1282, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_2ca5b70601', 'id': 'chatcmpl-DSfJAKvM6BtudLjFtdhWvPJmL6onl', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019d716b-2bec-7672-80b8-1f9b5afdfdfa-0', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'current weather in Louisiana'}, 'id': 'call_fzTSijP4ZHkAUDFoR6AMhwMh'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1258, 'output_tokens': 24, 'total_tokens': 1282, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
# {'configurable': {'thread_id': '3',
#   'checkpoint_ns': '',
#   'checkpoint_id': '1f133f07-e78c-680c-8002-a3fe5eb4279a'}}

# %%
abot.graph.get_state(thread)
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in LA?', additional_kwargs={}, response_metadata={}, id='c06c33ee-21be-4ee0-bac4-9780aec6bc08'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 24, 'prompt_tokens': 1258, 'total_tokens': 1282, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_2ca5b70601', 'id': 'chatcmpl-DSfJAKvM6BtudLjFtdhWvPJmL6onl', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019d716b-2bec-7672-80b8-1f9b5afdfdfa-0', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'current weather in Louisiana'}, 'id': 'call_fzTSijP4ZHkAUDFoR6AMhwMh', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1258, 'output_tokens': 24, 'total_tokens': 1282, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}, next=('action',), config={'configurable': {'thread_id': '3', 'checkpoint_ns': '', 'checkpoint_id': '1f133f07-e78c-680c-8002-a3fe5eb4279a'}}, metadata={'source': 'update', 'step': 2, 'parents': {}}, created_at='2026-04-09T08:45:43.220839+00:00', parent_config={'configurable': {'thread_id': '3', 'checkpoint_ns': '', 'checkpoint_id': '1f133f07-e6d1-6fe0-8001-1d5dd54aebc1'}}, tasks=(PregelTask(id='d9ad9e86-2a9f-67d6-e57a-da7de110c9cd', name='action', path=('__pregel_pull', 'action'), error=None, interrupts=(), state=None, result=None),), interrupts=())

# %%
for event in abot.graph.stream(None, thread):
    for v in event.values():
        print(v)
# Out:
# Calling: {'name': 'tavily_search', 'args': {'query': 'current weather in Louisiana'}, 'id': 'call_fzTSijP4ZHkAUDFoR6AMhwMh', 'type': 'tool_call'}
# Back to the model!
# {'messages': [ToolMessage(content='{\'query\': \'current weather in Louisiana\', \'follow_up_questions\': None, \'answer\': None, \'images\': [], \'results\': [{\'title\': \'Weather in Louisiana\', \'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'Louisiana\', \'region\': \'Missouri\', \'country\': \'United States of America\', \'lat\': 39.4411, \'lon\': -91.0551, \'tz_id\': \'America/Chicago\', \'localtime_epoch\': 1775724333, \'localtime\': \'2026-04-09 03:45\'}, \'current\': {\'last_updated_epoch\': 1775724300, \'last_updated\': \'2026-04-09 03:45\', \'temp_c\': 16.5, \'temp_f\': 61.7, \'is_day\': 0, \'condition\': {\'text\': \'Clear\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/night/113.png\', \'code\': 1000}, \'wind_mph\': 11.6, \'wind_kph\': 18.7, \'wind_degree\': 208, \'wind_dir\': \'SSW\', \'pressure_mb\': 1019.0, \'pressure_in\': 30.1, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 47, \'cloud\': 0, \'feelslike_c\': 16.5, \'feelslike_f\': 61.7, \'windchill_c\': 12.9, \'windchill_f\': 55.2, \'heatindex_c\': 14.1, \'heatindex_f\': 57.4, \'dewpoint_c\': 4.9, \'dewpoint_f\': 40.8, \'vis_km\': 16.0, \'vis_miles\': 9.0, \'uv\': 0.0, \'gust_mph\': 21.4, \'gust_kph\': 34.4}}", \'score\': 0.9999986, \'raw_content\': None}, {\'url\': \'https://www.weather25.com/north-america/usa/louisiana?page=month&month=September\', \'title\': \'Louisiana weather in September 2026 | Weather25.com\', \'content\': \'The weather in Louisiana in September is very hot. The average temperatures are between 75°F and 87°F, drinking water regularly is advisable.\', \'score\': 0.99984884, \'raw_content\': None}], \'response_time\': 1.59, \'request_id\': \'059e4d96-35e5-4907-a654-5b467e481493\'}', name='tavily_search', id='303f17cb-2376-46e2-adad-9b29c76dbb7c', tool_call_id='call_fzTSijP4ZHkAUDFoR6AMhwMh')]}
# {'messages': [HumanMessage(content='Whats the weather in LA?', additional_kwargs={}, response_metadata={}, id='c06c33ee-21be-4ee0-bac4-9780aec6bc08'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 24, 'prompt_tokens': 1258, 'total_tokens': 1282, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_2ca5b70601', 'id': 'chatcmpl-DSfJAKvM6BtudLjFtdhWvPJmL6onl', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019d716b-2bec-7672-80b8-1f9b5afdfdfa-0', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'current weather in Louisiana'}, 'id': 'call_fzTSijP4ZHkAUDFoR6AMhwMh', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1258, 'output_tokens': 24, 'total_tokens': 1282, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='{\'query\': \'current weather in Louisiana\', \'follow_up_questions\': None, \'answer\': None, \'images\': [], \'results\': [{\'title\': \'Weather in Louisiana\', \'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'Louisiana\', \'region\': \'Missouri\', \'country\': \'United States of America\', \'lat\': 39.4411, \'lon\': -91.0551, \'tz_id\': \'America/Chicago\', \'localtime_epoch\': 1775724333, \'localtime\': \'2026-04-09 03:45\'}, \'current\': {\'last_updated_epoch\': 1775724300, \'last_updated\': \'2026-04-09 03:45\', \'temp_c\': 16.5, \'temp_f\': 61.7, \'is_day\': 0, \'condition\': {\'text\': \'Clear\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/night/113.png\', \'code\': 1000}, \'wind_mph\': 11.6, \'wind_kph\': 18.7, \'wind_degree\': 208, \'wind_dir\': \'SSW\', \'pressure_mb\': 1019.0, \'pressure_in\': 30.1, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 47, \'cloud\': 0, \'feelslike_c\': 16.5, \'feelslike_f\': 61.7, \'windchill_c\': 12.9, \'windchill_f\': 55.2, \'heatindex_c\': 14.1, \'heatindex_f\': 57.4, \'dewpoint_c\': 4.9, \'dewpoint_f\': 40.8, \'vis_km\': 16.0, \'vis_miles\': 9.0, \'uv\': 0.0, \'gust_mph\': 21.4, \'gust_kph\': 34.4}}", \'score\': 0.9999986, \'raw_content\': None}, {\'url\': \'https://www.weather25.com/north-america/usa/louisiana?page=month&month=September\', \'title\': \'Louisiana weather in September 2026 | Weather25.com\', \'content\': \'The weather in Louisiana in September is very hot. The average temperatures are between 75°F and 87°F, drinking water regularly is advisable.\', \'score\': 0.99984884, \'raw_content\': None}], \'response_time\': 1.59, \'request_id\': \'059e4d96-35e5-4907-a654-5b467e481493\'}', name='tavily_search', id='303f17cb-2376-46e2-adad-9b29c76dbb7c', tool_call_id='call_fzTSijP4ZHkAUDFoR6AMhwMh'), AIMessage(content="The current weather in Louisiana is clear with a temperature of 61.7°F (16.5°C). The wind is blowing from the SSW at 11.6 mph, and there's no precipitation. The humidity level is 47%, and visibility is about 16 km.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 58, 'prompt_tokens': 1871, 'total_tokens': 1929, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1152}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_2ca5b70601', 'id': 'chatcmpl-DSfJEqCFdw4k50YsRPbh97ojRjs4g', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d716b-3a87-79c1-8d27-34606d48b89f-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1871, 'output_tokens': 58, 'total_tokens': 1929, 'input_tok ...
# {'messages': [AIMessage(content="The current weather in Louisiana is clear with a temperature of 61.7°F (16.5°C). The wind is blowing from the SSW at 11.6 mph, and there's no precipitation. The humidity level is 47%, and visibility is about 16 km.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 58, 'prompt_tokens': 1871, 'total_tokens': 1929, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1152}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_2ca5b70601', 'id': 'chatcmpl-DSfJEqCFdw4k50YsRPbh97ojRjs4g', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d716b-3a87-79c1-8d27-34606d48b89f-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1871, 'output_tokens': 58, 'total_tokens': 1929, 'input_token_details': {'audio': 0, 'cache_read': 1152}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}

# %% [markdown]
# ## Time Travel

# %%
states = []
for state in abot.graph.get_state_history(thread):
    print(state)
    print('--')
    states.append(state)
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in LA?', additional_kwargs={}, response_metadata={}, id='c06c33ee-21be-4ee0-bac4-9780aec6bc08'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 24, 'prompt_tokens': 1258, 'total_tokens': 1282, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_2ca5b70601', 'id': 'chatcmpl-DSfJAKvM6BtudLjFtdhWvPJmL6onl', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019d716b-2bec-7672-80b8-1f9b5afdfdfa-0', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'current weather in Louisiana'}, 'id': 'call_fzTSijP4ZHkAUDFoR6AMhwMh', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1258, 'output_tokens': 24, 'total_tokens': 1282, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='{\'query\': \'current weather in Louisiana\', \'follow_up_questions\': None, \'answer\': None, \'images\': [], \'results\': [{\'title\': \'Weather in Louisiana\', \'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'Louisiana\', \'region\': \'Missouri\', \'country\': \'United States of America\', \'lat\': 39.4411, \'lon\': -91.0551, \'tz_id\': \'America/Chicago\', \'localtime_epoch\': 1775724333, \'localtime\': \'2026-04-09 03:45\'}, \'current\': {\'last_updated_epoch\': 1775724300, \'last_updated\': \'2026-04-09 03:45\', \'temp_c\': 16.5, \'temp_f\': 61.7, \'is_day\': 0, \'condition\': {\'text\': \'Clear\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/night/113.png\', \'code\': 1000}, \'wind_mph\': 11.6, \'wind_kph\': 18.7, \'wind_degree\': 208, \'wind_dir\': \'SSW\', \'pressure_mb\': 1019.0, \'pressure_in\': 30.1, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 47, \'cloud\': 0, \'feelslike_c\': 16.5, \'feelslike_f\': 61.7, \'windchill_c\': 12.9, \'windchill_f\': 55.2, \'heatindex_c\': 14.1, \'heatindex_f\': 57.4, \'dewpoint_c\': 4.9, \'dewpoint_f\': 40.8, \'vis_km\': 16.0, \'vis_miles\': 9.0, \'uv\': 0.0, \'gust_mph\': 21.4, \'gust_kph\': 34.4}}", \'score\': 0.9999986, \'raw_content\': None}, {\'url\': \'https://www.weather25.com/north-america/usa/louisiana?page=month&month=September\', \'title\': \'Louisiana weather in September 2026 | Weather25.com\', \'content\': \'The weather in Louisiana in September is very hot. The average temperatures are between 75°F and 87°F, drinking water regularly is advisable.\', \'score\': 0.99984884, \'raw_content\': None}], \'response_time\': 1.59, \'request_id\': \'059e4d96-35e5-4907-a654-5b467e481493\'}', name='tavily_search', id='303f17cb-2376-46e2-adad-9b29c76dbb7c', tool_call_id='call_fzTSijP4ZHkAUDFoR6AMhwMh'), AIMessage(content="The current weather in Louisiana is clear with a temperature of 61.7°F (16.5°C). The wind is blowing from the SSW at 11.6 mph, and there's no precipitation. The humidity level is 47%, and visibility is about 16 km.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 58, 'prompt_tokens': 1871, 'total_tokens': 1929, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1152}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_2ca5b70601', 'id': 'chatcmpl-DSfJEqCFdw4k50YsRPbh97ojRjs4g', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d716b-3a87-79c1-8d27-34606d48b89f-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1871, 'output_tokens': 58, 'total_toke ...
# --
# StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in LA?', additional_kwargs={}, response_metadata={}, id='c06c33ee-21be-4ee0-bac4-9780aec6bc08'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 24, 'prompt_tokens': 1258, 'total_tokens': 1282, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_2ca5b70601', 'id': 'chatcmpl-DSfJAKvM6BtudLjFtdhWvPJmL6onl', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019d716b-2bec-7672-80b8-1f9b5afdfdfa-0', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'current weather in Louisiana'}, 'id': 'call_fzTSijP4ZHkAUDFoR6AMhwMh', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1258, 'output_tokens': 24, 'total_tokens': 1282, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='{\'query\': \'current weather in Louisiana\', \'follow_up_questions\': None, \'answer\': None, \'images\': [], \'results\': [{\'title\': \'Weather in Louisiana\', \'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'Louisiana\', \'region\': \'Missouri\', \'country\': \'United States of America\', \'lat\': 39.4411, \'lon\': -91.0551, \'tz_id\': \'America/Chicago\', \'localtime_epoch\': 1775724333, \'localtime\': \'2026-04-09 03:45\'}, \'current\': {\'last_updated_epoch\': 1775724300, \'last_updated\': \'2026-04-09 03:45\', \'temp_c\': 16.5, \'temp_f\': 61.7, \'is_day\': 0, \'condition\': {\'text\': \'Clear\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/night/113.png\', \'code\': 1000}, \'wind_mph\': 11.6, \'wind_kph\': 18.7, \'wind_degree\': 208, \'wind_dir\': \'SSW\', \'pressure_mb\': 1019.0, \'pressure_in\': 30.1, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 47, \'cloud\': 0, \'feelslike_c\': 16.5, \'feelslike_f\': 61.7, \'windchill_c\': 12.9, \'windchill_f\': 55.2, \'heatindex_c\': 14.1, \'heatindex_f\': 57.4, \'dewpoint_c\': 4.9, \'dewpoint_f\': 40.8, \'vis_km\': 16.0, \'vis_miles\': 9.0, \'uv\': 0.0, \'gust_mph\': 21.4, \'gust_kph\': 34.4}}", \'score\': 0.9999986, \'raw_content\': None}, {\'url\': \'https://www.weather25.com/north-america/usa/louisiana?page=month&month=September\', \'title\': \'Louisiana weather in September 2026 | Weather25.com\', \'content\': \'The weather in Louisiana in September is very hot. The average temperatures are between 75°F and 87°F, drinking water regularly is advisable.\', \'score\': 0.99984884, \'raw_content\': None}], \'response_time\': 1.59, \'request_id\': \'059e4d96-35e5-4907-a654-5b467e481493\'}', name='tavily_search', id='303f17cb-2376-46e2-adad-9b29c76dbb7c', tool_call_id='call_fzTSijP4ZHkAUDFoR6AMhwMh')]}, next=('llm',), config={'configurable': {'thread_id': '3', 'checkpoint_ns': '', 'checkpoint_id': '1f133f08-01f7-64ad-8003-556daac76d63'}}, metadata={'source': 'loop', 'step': 3, 'parents': {}}, created_at='2026-04-09T08:45:45.990878+00:00', parent_config={'configurable': {'thread_id': '3', 'checkpoint_ns': '', 'checkpoint_id': '1f133f07-e78c-680c-8002-a3fe5eb4279a'}}, tasks=(PregelTask(id='506b3391-35ee-9f30-8d05-b3688ec21891', name='llm', path=('__pregel_pull', 'llm'), error=None, interrupts=(), state=None, result={'messages': [AIMessage(content="The current weather in Louisiana is clear with a temperature of 61.7°F (16.5°C). The wind is blowing from the SSW at 11.6 mph, and there's no precipitation. The humidity level is 47%, and visibility is about 16 km.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 58, 'prompt_tokens': 1871, 'total_tokens': 1929, 'completion_tokens_details': {'accepted_prediction_toke ...
# --
# StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in LA?', additional_kwargs={}, response_metadata={}, id='c06c33ee-21be-4ee0-bac4-9780aec6bc08'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 24, 'prompt_tokens': 1258, 'total_tokens': 1282, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_2ca5b70601', 'id': 'chatcmpl-DSfJAKvM6BtudLjFtdhWvPJmL6onl', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019d716b-2bec-7672-80b8-1f9b5afdfdfa-0', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'current weather in Louisiana'}, 'id': 'call_fzTSijP4ZHkAUDFoR6AMhwMh', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1258, 'output_tokens': 24, 'total_tokens': 1282, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}, next=('action',), config={'configurable': {'thread_id': '3', 'checkpoint_ns': '', 'checkpoint_id': '1f133f07-e78c-680c-8002-a3fe5eb4279a'}}, metadata={'source': 'update', 'step': 2, 'parents': {}}, created_at='2026-04-09T08:45:43.220839+00:00', parent_config={'configurable': {'thread_id': '3', 'checkpoint_ns': '', 'checkpoint_id': '1f133f07-e6d1-6fe0-8001-1d5dd54aebc1'}}, tasks=(PregelTask(id='d9ad9e86-2a9f-67d6-e57a-da7de110c9cd', name='action', path=('__pregel_pull', 'action'), error=None, interrupts=(), state=None, result={'messages': [ToolMessage(content='{\'query\': \'current weather in Louisiana\', \'follow_up_questions\': None, \'answer\': None, \'images\': [], \'results\': [{\'title\': \'Weather in Louisiana\', \'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'Louisiana\', \'region\': \'Missouri\', \'country\': \'United States of America\', \'lat\': 39.4411, \'lon\': -91.0551, \'tz_id\': \'America/Chicago\', \'localtime_epoch\': 1775724333, \'localtime\': \'2026-04-09 03:45\'}, \'current\': {\'last_updated_epoch\': 1775724300, \'last_updated\': \'2026-04-09 03:45\', \'temp_c\': 16.5, \'temp_f\': 61.7, \'is_day\': 0, \'condition\': {\'text\': \'Clear\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/night/113.png\', \'code\': 1000}, \'wind_mph\': 11.6, \'wind_kph\': 18.7, \'wind_degree\': 208, \'wind_dir\': \'SSW\', \'pressure_mb\': 1019.0, \'pressure_in\': 30.1, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 47, \'cloud\': 0, \'feelslike_c\': 16.5, \'feelslike_f\': 61.7, \'windchill_c\': 12.9, \'windchill_f\': 55.2, \'heatindex_c\': 14.1, \'heatindex_f\': 57.4, \'dewpoint_c\': 4.9, \'dewpoint_f\': 40.8, \'vis_km\': 16.0, \'vis_miles\': 9.0, \'uv\': 0.0, \'gust_mph\': 21.4, \'gust_kph\': 34.4}}", \'score\': 0.9999986, \'raw_content\': None}, {\'url\': \'https://www.weather25.com/north-america/usa/louisiana?page=month&month=September\', \'title\': \'Louisiana weather in September 2026 | Weather25.com\', \'content\': \'The weather in Louisiana in September is very hot. The average temperatures are between 75°F and 87°F, drinking water regularly is advisable.\', \'score\': 0.99984884, \'raw_content\': None}], \'response_time\': 1.59, \'request_id\': \'059e4d96-35e5-4907-a654-5b467e481493\'}', name='tavily_search', tool_call_id='call_fzTSijP4ZHkAUDFoR6AMhwMh')]}),), interrupts=())
# --
# StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in LA?', additional_kwargs={}, response_metadata={}, id='c06c33ee-21be-4ee0-bac4-9780aec6bc08'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 24, 'prompt_tokens': 1258, 'total_tokens': 1282, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_2ca5b70601', 'id': 'chatcmpl-DSfJAKvM6BtudLjFtdhWvPJmL6onl', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019d716b-2bec-7672-80b8-1f9b5afdfdfa-0', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'current weather in Los Angeles', 'topic': 'news'}, 'id': 'call_fzTSijP4ZHkAUDFoR6AMhwMh', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1258, 'output_tokens': 24, 'total_tokens': 1282, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}, next=('action',), config={'configurable': {'thread_id': '3', 'checkpoint_ns': '', 'checkpoint_id': '1f133f07-e6d1-6fe0-8001-1d5dd54aebc1'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-04-09T08:45:43.144444+00:00', parent_config={'configurable': {'thread_id': '3', 'checkpoint_ns': '', 'checkpoint_id': '1f133f07-de4c-6fd8-8000-d01c222cc9a4'}}, tasks=(PregelTask(id='a9de5d5d-490e-3a38-73d5-927c000ed692', name='action', path=('__pregel_pull', 'action'), error=None, interrupts=(), state=None, result=None),), interrupts=())
# --
# StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in LA?', additional_kwargs={}, response_metadata={}, id='c06c33ee-21be-4ee0-bac4-9780aec6bc08')]}, next=('llm',), config={'configurable': {'thread_id': '3', 'checkpoint_ns': '', 'checkpoint_id': '1f133f07-de4c-6fd8-8000-d01c222cc9a4'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2026-04-09T08:45:42.251106+00:00', parent_config={'configurable': {'thread_id': '3', 'checkpoint_ns': '', 'checkpoint_id': '1f133f07-de49-6726-bfff-b5a7a4e440c4'}}, tasks=(PregelTask(id='90fa80e3-3ac6-a4cd-aa73-e1b790c6b85e', name='llm', path=('__pregel_pull', 'llm'), error=None, interrupts=(), state=None, result={'messages': [AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 24, 'prompt_tokens': 1258, 'total_tokens': 1282, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_2ca5b70601', 'id': 'chatcmpl-DSfJAKvM6BtudLjFtdhWvPJmL6onl', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019d716b-2bec-7672-80b8-1f9b5afdfdfa-0', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'current weather in Los Angeles', 'topic': 'news'}, 'id': 'call_fzTSijP4ZHkAUDFoR6AMhwMh', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1258, 'output_tokens': 24, 'total_tokens': 1282, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}),), interrupts=())
# --
# StateSnapshot(values={'messages': []}, next=('__start__',), config={'configurable': {'thread_id': '3', 'checkpoint_ns': '', 'checkpoint_id': '1f133f07-de49-6726-bfff-b5a7a4e440c4'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2026-04-09T08:45:42.249654+00:00', parent_config=None, tasks=(PregelTask(id='dac0da72-995a-f576-d706-1d46a765d3c5', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'messages': [HumanMessage(content='Whats the weather in LA?', additional_kwargs={}, response_metadata={}, id='c06c33ee-21be-4ee0-bac4-9780aec6bc08')]}),), interrupts=())
# --

# %% [markdown]
# To fetch the same state as was filmed, the offset below is changed to `-3` from `-1`. This accounts for the initial state `__start__` and the first state that are now stored to state memory with the latest version of software.

# %%
to_replay = states[-3]

# %%
to_replay
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in LA?', additional_kwargs={}, response_metadata={}, id='c06c33ee-21be-4ee0-bac4-9780aec6bc08'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 24, 'prompt_tokens': 1258, 'total_tokens': 1282, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_2ca5b70601', 'id': 'chatcmpl-DSfJAKvM6BtudLjFtdhWvPJmL6onl', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019d716b-2bec-7672-80b8-1f9b5afdfdfa-0', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'current weather in Los Angeles', 'topic': 'news'}, 'id': 'call_fzTSijP4ZHkAUDFoR6AMhwMh', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1258, 'output_tokens': 24, 'total_tokens': 1282, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}, next=('action',), config={'configurable': {'thread_id': '3', 'checkpoint_ns': '', 'checkpoint_id': '1f133f07-e6d1-6fe0-8001-1d5dd54aebc1'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-04-09T08:45:43.144444+00:00', parent_config={'configurable': {'thread_id': '3', 'checkpoint_ns': '', 'checkpoint_id': '1f133f07-de4c-6fd8-8000-d01c222cc9a4'}}, tasks=(PregelTask(id='a9de5d5d-490e-3a38-73d5-927c000ed692', name='action', path=('__pregel_pull', 'action'), error=None, interrupts=(), state=None, result=None),), interrupts=())

# %%
for event in abot.graph.stream(None, to_replay.config):
    for k, v in event.items():
        print(v)
# Out:
# Calling: {'name': 'tavily_search', 'args': {'query': 'current weather in Los Angeles', 'topic': 'news'}, 'id': 'call_fzTSijP4ZHkAUDFoR6AMhwMh', 'type': 'tool_call'}
# Back to the model!
# {'messages': [ToolMessage(content="{'query': 'current weather in Los Angeles', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://www.latimes.com/california/story/2026-04-06/weather-rain-thunderstorms-cooler-temperatures-forecast', 'title': 'Rain, possible thunderstorms will break SoCal heat streak this week, forecasters say - Los Angeles Times', 'score': 0.5278769, 'published_date': 'Mon, 06 Apr 2026 10:00:00 GMT', 'content': '# Rain, possible thunderstorms will break SoCal heat streak this week, forecasters say. After a record-breaking warm spell last month that made late winter feel like midsummer, the heat continued into April, with Santa Ana winds fueling local wildfires. But Southern California will feel more like spring this week as cooler, wetter weather is on the way, forecasters say. Rain could begin as early as Thursday in Los Angeles and Ventura counties and continue through Saturday, with a 70% chance of precipitation, according to the National Weather Service. SoCal residents can expect up to 1 inch of rain, Rose Schoenfeld, a meteorologist with the National Weather Service, told The Times. According to the weather service, it’s unclear yet how hot it will be in April. Cooler weather, however, is on the horizon this week, which includes a 10% to 20% chance of thunderstorms, the weather service warned. Filmmaker Ondi Timoner was overseas shooting a documentary when the Eaton Fire destroyed her home of 14 years, and wiped her entire neighborhood away.', 'raw_content': None}, {'url': 'https://www.cbsnews.com/losangeles/video/amber-lees-next-weather-forecast-145/', 'title': 'Amber Lee’s NEXT Weather forecast - CBS News', 'score': 0.40967003, 'published_date': 'Tue, 07 Apr 2026 13:44:00 GMT', 'content': '# Amber Lee’s NEXT Weather forecast. Temperatures on Tuesday in Southern California will continue to be about 1 to 3 degrees cooler. There will be an increase in sea breeze before a chance of rain returns over the weekend.', 'raw_content': None}], 'response_time': 0.25, 'request_id': '86654cbe-b079-43e2-a235-82d832cab6ad'}", name='tavily_search', id='50ebb649-4b93-4458-951a-a55ff99a1323', tool_call_id='call_fzTSijP4ZHkAUDFoR6AMhwMh')]}
# {'messages': [HumanMessage(content='Whats the weather in LA?', additional_kwargs={}, response_metadata={}, id='c06c33ee-21be-4ee0-bac4-9780aec6bc08'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 24, 'prompt_tokens': 1258, 'total_tokens': 1282, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_2ca5b70601', 'id': 'chatcmpl-DSfJAKvM6BtudLjFtdhWvPJmL6onl', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019d716b-2bec-7672-80b8-1f9b5afdfdfa-0', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'current weather in Los Angeles', 'topic': 'news'}, 'id': 'call_fzTSijP4ZHkAUDFoR6AMhwMh', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1258, 'output_tokens': 24, 'total_tokens': 1282, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content="{'query': 'current weather in Los Angeles', 'follow_up_questions': None, 'answer': None, 'images': [], 'results': [{'url': 'https://www.latimes.com/california/story/2026-04-06/weather-rain-thunderstorms-cooler-temperatures-forecast', 'title': 'Rain, possible thunderstorms will break SoCal heat streak this week, forecasters say - Los Angeles Times', 'score': 0.5278769, 'published_date': 'Mon, 06 Apr 2026 10:00:00 GMT', 'content': '# Rain, possible thunderstorms will break SoCal heat streak this week, forecasters say. After a record-breaking warm spell last month that made late winter feel like midsummer, the heat continued into April, with Santa Ana winds fueling local wildfires. But Southern California will feel more like spring this week as cooler, wetter weather is on the way, forecasters say. Rain could begin as early as Thursday in Los Angeles and Ventura counties and continue through Saturday, with a 70% chance of precipitation, according to the National Weather Service. SoCal residents can expect up to 1 inch of rain, Rose Schoenfeld, a meteorologist with the National Weather Service, told The Times. According to the weather service, it’s unclear yet how hot it will be in April. Cooler weather, however, is on the horizon this week, which includes a 10% to 20% chance of thunderstorms, the weather service warned. Filmmaker Ondi Timoner was overseas shooting a documentary when the Eaton Fire destroyed her home of 14 years, and wiped her entire neighborhood away.', 'raw_content': None}, {'url': 'https://www.cbsnews.com/losangeles/video/amber-lees-next-weather-forecast-145/', 'title': 'Amber Lee’s NEXT Weather forecast - CBS News', 'score': 0.40967003, 'published_date': 'Tue, 07 Apr 2026 13:44:00 GMT', 'content': '# Amber Lee’s NEXT Weather forecast. Temperatures on Tuesday in Southern California will continue to be about 1 to 3 degrees cooler. There will be an increase in sea breeze before a chance of rain returns over the weekend.', 'raw_content': None}], 'response_time': 0.25, 'request_id': '86654cbe-b079-43e2-a235-82d832cab6ad'}", name='tavily_search', id='50ebb649-4b93-4458-951a-a55ff99a1323', tool_call_id='call_fzTSijP4ZHkAUDFoR6AMhwMh'), AIMessage(content='The current weather forecast for Los Angeles indicates cooler temperatures with a chance of rain starting as early as Thursday, continuing through Saturday with a 70% chance of precipitation. Residents can expect up to 1 inch of rain and a 10% to 20% chance of thunderstorms. Temperatures are slightly cooler, with an increase in sea breeze expected before the rain returns over the weekend.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 78, 'prompt_tokens': 1801, 'total_tokens': 1879, 'completion_tokens_details': {'accepted_prediction_toke ...
# {'messages': [AIMessage(content='The current weather forecast for Los Angeles indicates cooler temperatures with a chance of rain starting as early as Thursday, continuing through Saturday with a 70% chance of precipitation. Residents can expect up to 1 inch of rain and a 10% to 20% chance of thunderstorms. Temperatures are slightly cooler, with an increase in sea breeze expected before the rain returns over the weekend.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 78, 'prompt_tokens': 1801, 'total_tokens': 1879, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_2ca5b70601', 'id': 'chatcmpl-DSfJHulgv19rEJKTmiF2XZURFHM6M', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d716b-44ee-7e93-b212-48e2ae0cc1b2-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1801, 'output_tokens': 78, 'total_tokens': 1879, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}

# %% [markdown]
# ## Go back in time and edit

# %%
to_replay
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in LA?', additional_kwargs={}, response_metadata={}, id='c06c33ee-21be-4ee0-bac4-9780aec6bc08'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 24, 'prompt_tokens': 1258, 'total_tokens': 1282, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_2ca5b70601', 'id': 'chatcmpl-DSfJAKvM6BtudLjFtdhWvPJmL6onl', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019d716b-2bec-7672-80b8-1f9b5afdfdfa-0', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'current weather in Los Angeles', 'topic': 'news'}, 'id': 'call_fzTSijP4ZHkAUDFoR6AMhwMh', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1258, 'output_tokens': 24, 'total_tokens': 1282, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}, next=('action',), config={'configurable': {'thread_id': '3', 'checkpoint_ns': '', 'checkpoint_id': '1f133f07-e6d1-6fe0-8001-1d5dd54aebc1'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-04-09T08:45:43.144444+00:00', parent_config={'configurable': {'thread_id': '3', 'checkpoint_ns': '', 'checkpoint_id': '1f133f07-de4c-6fd8-8000-d01c222cc9a4'}}, tasks=(PregelTask(id='a9de5d5d-490e-3a38-73d5-927c000ed692', name='action', path=('__pregel_pull', 'action'), error=None, interrupts=(), state=None, result=None),), interrupts=())

# %%
_id = to_replay.values['messages'][-1].tool_calls[0]['id']
to_replay.values['messages'][-1].tool_calls = [{'name': 'tavily_search',
  'args': {'query': 'current weather in LA, accuweather'},
  'id': _id}]

# %%
branch_state = abot.graph.update_state(to_replay.config, to_replay.values)
# Out:
# {'messages': [HumanMessage(content='Whats the weather in LA?', additional_kwargs={}, response_metadata={}, id='c06c33ee-21be-4ee0-bac4-9780aec6bc08'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 24, 'prompt_tokens': 1258, 'total_tokens': 1282, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_2ca5b70601', 'id': 'chatcmpl-DSfJAKvM6BtudLjFtdhWvPJmL6onl', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019d716b-2bec-7672-80b8-1f9b5afdfdfa-0', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'current weather in LA, accuweather'}, 'id': 'call_fzTSijP4ZHkAUDFoR6AMhwMh'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1258, 'output_tokens': 24, 'total_tokens': 1282, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}

# %%
for event in abot.graph.stream(None, branch_state):
    for k, v in event.items():
        if k != "__end__":
            print(v)
# Out:
# Calling: {'name': 'tavily_search', 'args': {'query': 'current weather in LA, accuweather'}, 'id': 'call_fzTSijP4ZHkAUDFoR6AMhwMh', 'type': 'tool_call'}
# Back to the model!
# {'messages': [ToolMessage(content='{\'query\': \'current weather in LA, accuweather\', \'follow_up_questions\': None, \'answer\': None, \'images\': [], \'results\': [{\'title\': \'Weather in Los Angeles, CA\', \'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'Los Angeles\', \'region\': \'California\', \'country\': \'United States of America\', \'lat\': 34.0522, \'lon\': -118.2428, \'tz_id\': \'America/Los_Angeles\', \'localtime_epoch\': 1775724042, \'localtime\': \'2026-04-09 01:40\'}, \'current\': {\'last_updated_epoch\': 1775723400, \'last_updated\': \'2026-04-09 01:30\', \'temp_c\': 17.2, \'temp_f\': 63.0, \'is_day\': 0, \'condition\': {\'text\': \'Clear\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/night/113.png\', \'code\': 1000}, \'wind_mph\': 3.4, \'wind_kph\': 5.4, \'wind_degree\': 162, \'wind_dir\': \'SSE\', \'pressure_mb\': 1014.0, \'pressure_in\': 29.94, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 84, \'cloud\': 0, \'feelslike_c\': 17.2, \'feelslike_f\': 63.0, \'windchill_c\': 15.6, \'windchill_f\': 60.1, \'heatindex_c\': 15.6, \'heatindex_f\': 60.1, \'dewpoint_c\': 14.2, \'dewpoint_f\': 57.7, \'vis_km\': 16.0, \'vis_miles\': 9.0, \'uv\': 0.0, \'gust_mph\': 4.5, \'gust_kph\': 7.2}}", \'score\': 0.9999913, \'raw_content\': None}, {\'url\': \'https://www.accuweather.com/en/us/los-angeles/90012/april-weather/347625\', \'title\': \'Los Angeles, CA Monthly Weather - AccuWeather\', \'content\': "April Weather in Los Angeles. Los Angeles\'s April 2026 forecast shows daily high temperatures ranging from 66° to 77°, with overnight lows between 50° and 60°.", \'score\': 0.9999521, \'raw_content\': None}], \'response_time\': 1.53, \'request_id\': \'49a84c49-b56e-4ec0-a5b2-e6b7b1cc4104\'}', name='tavily_search', id='72289b0a-0b11-411d-a892-d94b499ac4cf', tool_call_id='call_fzTSijP4ZHkAUDFoR6AMhwMh')]}
# {'messages': [HumanMessage(content='Whats the weather in LA?', additional_kwargs={}, response_metadata={}, id='c06c33ee-21be-4ee0-bac4-9780aec6bc08'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 24, 'prompt_tokens': 1258, 'total_tokens': 1282, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_2ca5b70601', 'id': 'chatcmpl-DSfJAKvM6BtudLjFtdhWvPJmL6onl', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019d716b-2bec-7672-80b8-1f9b5afdfdfa-0', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'current weather in LA, accuweather'}, 'id': 'call_fzTSijP4ZHkAUDFoR6AMhwMh', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1258, 'output_tokens': 24, 'total_tokens': 1282, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='{\'query\': \'current weather in LA, accuweather\', \'follow_up_questions\': None, \'answer\': None, \'images\': [], \'results\': [{\'title\': \'Weather in Los Angeles, CA\', \'url\': \'https://www.weatherapi.com/\', \'content\': "{\'location\': {\'name\': \'Los Angeles\', \'region\': \'California\', \'country\': \'United States of America\', \'lat\': 34.0522, \'lon\': -118.2428, \'tz_id\': \'America/Los_Angeles\', \'localtime_epoch\': 1775724042, \'localtime\': \'2026-04-09 01:40\'}, \'current\': {\'last_updated_epoch\': 1775723400, \'last_updated\': \'2026-04-09 01:30\', \'temp_c\': 17.2, \'temp_f\': 63.0, \'is_day\': 0, \'condition\': {\'text\': \'Clear\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/night/113.png\', \'code\': 1000}, \'wind_mph\': 3.4, \'wind_kph\': 5.4, \'wind_degree\': 162, \'wind_dir\': \'SSE\', \'pressure_mb\': 1014.0, \'pressure_in\': 29.94, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 84, \'cloud\': 0, \'feelslike_c\': 17.2, \'feelslike_f\': 63.0, \'windchill_c\': 15.6, \'windchill_f\': 60.1, \'heatindex_c\': 15.6, \'heatindex_f\': 60.1, \'dewpoint_c\': 14.2, \'dewpoint_f\': 57.7, \'vis_km\': 16.0, \'vis_miles\': 9.0, \'uv\': 0.0, \'gust_mph\': 4.5, \'gust_kph\': 7.2}}", \'score\': 0.9999913, \'raw_content\': None}, {\'url\': \'https://www.accuweather.com/en/us/los-angeles/90012/april-weather/347625\', \'title\': \'Los Angeles, CA Monthly Weather - AccuWeather\', \'content\': "April Weather in Los Angeles. Los Angeles\'s April 2026 forecast shows daily high temperatures ranging from 66° to 77°, with overnight lows between 50° and 60°.", \'score\': 0.9999521, \'raw_content\': None}], \'response_time\': 1.53, \'request_id\': \'49a84c49-b56e-4ec0-a5b2-e6b7b1cc4104\'}', name='tavily_search', id='72289b0a-0b11-411d-a892-d94b499ac4cf', tool_call_id='call_fzTSijP4ZHkAUDFoR6AMhwMh'), AIMessage(content='The current weather in Los Angeles is clear with a temperature of 63°F (17.2°C). The wind is coming from the south-southeast at 3.4 mph (5.4 kph), and the humidity level is 84%. There is no current precipitation and the atmospheric pressure is 1014 mb. Visibility is 16 km (9 miles).', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 77, 'prompt_tokens': 1895, 'total_tokens': 1972, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1152}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_9860921a69', 'id': 'chatcmpl-DSfJLGNl5znrv1Vv28jBaVbKSPZiD', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d716b-5572-7841-990d-7fad01872345-0', tool_calls=[], invalid_tool_calls ...
# {'messages': [AIMessage(content='The current weather in Los Angeles is clear with a temperature of 63°F (17.2°C). The wind is coming from the south-southeast at 3.4 mph (5.4 kph), and the humidity level is 84%. There is no current precipitation and the atmospheric pressure is 1014 mb. Visibility is 16 km (9 miles).', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 77, 'prompt_tokens': 1895, 'total_tokens': 1972, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 1152}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_9860921a69', 'id': 'chatcmpl-DSfJLGNl5znrv1Vv28jBaVbKSPZiD', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d716b-5572-7841-990d-7fad01872345-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1895, 'output_tokens': 77, 'total_tokens': 1972, 'input_token_details': {'audio': 0, 'cache_read': 1152}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}

# %% [markdown]
# ## Add message to a state at a given time

# %%
to_replay
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in LA?', additional_kwargs={}, response_metadata={}, id='c06c33ee-21be-4ee0-bac4-9780aec6bc08'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 24, 'prompt_tokens': 1258, 'total_tokens': 1282, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_2ca5b70601', 'id': 'chatcmpl-DSfJAKvM6BtudLjFtdhWvPJmL6onl', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019d716b-2bec-7672-80b8-1f9b5afdfdfa-0', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'current weather in LA, accuweather'}, 'id': 'call_fzTSijP4ZHkAUDFoR6AMhwMh'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1258, 'output_tokens': 24, 'total_tokens': 1282, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}, next=('action',), config={'configurable': {'thread_id': '3', 'checkpoint_ns': '', 'checkpoint_id': '1f133f07-e6d1-6fe0-8001-1d5dd54aebc1'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-04-09T08:45:43.144444+00:00', parent_config={'configurable': {'thread_id': '3', 'checkpoint_ns': '', 'checkpoint_id': '1f133f07-de4c-6fd8-8000-d01c222cc9a4'}}, tasks=(PregelTask(id='a9de5d5d-490e-3a38-73d5-927c000ed692', name='action', path=('__pregel_pull', 'action'), error=None, interrupts=(), state=None, result=None),), interrupts=())

# %%
_id = to_replay.values['messages'][-1].tool_calls[0]['id']

# %%
state_update = {"messages": [ToolMessage(
    tool_call_id=_id,
    name="tavily_search",
    content="54 degree celcius",
)]}

# %%
branch_and_add = abot.graph.update_state(
    to_replay.config,
    state_update,
    as_node="action")

# %%
for event in abot.graph.stream(None, branch_and_add):
    for k, v in event.items():
        print(v)
# Out:
# {'messages': [HumanMessage(content='Whats the weather in LA?', additional_kwargs={}, response_metadata={}, id='c06c33ee-21be-4ee0-bac4-9780aec6bc08'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 24, 'prompt_tokens': 1258, 'total_tokens': 1282, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_2ca5b70601', 'id': 'chatcmpl-DSfJAKvM6BtudLjFtdhWvPJmL6onl', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019d716b-2bec-7672-80b8-1f9b5afdfdfa-0', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'current weather in Los Angeles', 'topic': 'news'}, 'id': 'call_fzTSijP4ZHkAUDFoR6AMhwMh', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1258, 'output_tokens': 24, 'total_tokens': 1282, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='54 degree celcius', name='tavily_search', id='6f465a22-11ec-49de-820d-4c5efd0da002', tool_call_id='call_fzTSijP4ZHkAUDFoR6AMhwMh'), AIMessage(content='The current temperature in Los Angeles is 54°F (12°C).', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 1296, 'total_tokens': 1311, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_9860921a69', 'id': 'chatcmpl-DSfJMbDNfiq0m4TuuwOLtYbwdgbML', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d716b-5ad5-76e0-b288-7dbc8e4cd715-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1296, 'output_tokens': 15, 'total_tokens': 1311, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
# {'messages': [AIMessage(content='The current temperature in Los Angeles is 54°F (12°C).', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 1296, 'total_tokens': 1311, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_9860921a69', 'id': 'chatcmpl-DSfJMbDNfiq0m4TuuwOLtYbwdgbML', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019d716b-5ad5-76e0-b288-7dbc8e4cd715-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1296, 'output_tokens': 15, 'total_tokens': 1311, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}

# %% [markdown]
# # Extra Practice

# %% [markdown]
# ## Build a small graph
# This is a small simple graph you can tinker with if you want more insight into controlling state memory.

# %%
from dotenv import load_dotenv

_ = load_dotenv()

# %%
from langgraph.graph import StateGraph, START, END
from typing import Annotated
from typing_extensions import TypedDict
import operator
from langgraph.checkpoint.memory import MemorySaver

# %% [markdown]
# Define a simple 2 node graph with the following state:
# -`lnode`: last node
# -`scratch`: a scratchpad location
# -`count` : a counter that is incremented each step

# %%
class AgentState(TypedDict):
    lnode: str
    scratch: str
    count: Annotated[int, operator.add]

# %%
def node1(state: AgentState):
    print(f"node1, count:{state['count']}")
    return {"lnode": "node_1",
            "count": 1,
           }
def node2(state: AgentState):
    print(f"node2, count:{state['count']}")
    return {"lnode": "node_2",
            "count": 1,
           }

# %% [markdown]
# The graph goes N1->N2->N1... but breaks after count reaches 3.

# %%
def should_continue(state):
    return state["count"] < 3

# %%
builder = StateGraph(AgentState)
builder.add_node("Node1", node1)
builder.add_node("Node2", node2)

builder.add_edge("Node1", "Node2")
builder.add_conditional_edges("Node2",
                              should_continue,
                              {True: "Node1", False: END})
builder.add_edge(START, "Node1")

# %%
memory = MemorySaver()
graph = builder.compile(checkpointer=memory)

# %% [markdown]
# ### Run it!
# Now, set the thread and run!

# %%
thread = {"configurable": {"thread_id": str(1)}}
graph.invoke({"count":0, "scratch":"hi"},thread)
# Out:
# node1, count:0
# node2, count:1
# node1, count:2
# node2, count:3
# {'lnode': 'node_2', 'scratch': 'hi', 'count': 4}

# %% [markdown]
# ### Look at current state

# %% [markdown]
# Get the current state. Note the `values` which are the AgentState. Note the `config` and the `thread_ts`. You will be using those to refer to snapshots below.

# %%
graph.get_state(thread)
# Out:
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hi', 'count': 4}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f133f08-5999-6ba7-8004-6b9cec0059f9'}}, metadata={'source': 'loop', 'step': 4, 'parents': {}}, created_at='2026-04-09T08:45:55.180023+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f133f08-5998-67f3-8003-4ddd7f24492d'}}, tasks=(), interrupts=())

# %% [markdown]
# View all the statesnapshots in memory. You can use the displayed `count` agentstate variable to help track what you see. Notice the most recent snapshots are returned by the iterator first. Also note that there is a handy `step` variable in the metadata that counts the number of steps in the graph execution. This is a bit detailed - but you can also notice that the *parent_config* is the *config* of the previous node. At initial startup, additional states are inserted into memory to create a parent. This is something to check when you branch or *time travel* below.

# %% [markdown]
# ### Look at state history

# %%
for state in graph.get_state_history(thread):
    print(state, "\n")
# Out:
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hi', 'count': 4}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f133f08-5999-6ba7-8004-6b9cec0059f9'}}, metadata={'source': 'loop', 'step': 4, 'parents': {}}, created_at='2026-04-09T08:45:55.180023+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f133f08-5998-67f3-8003-4ddd7f24492d'}}, tasks=(), interrupts=())
#
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hi', 'count': 3}, next=('Node2',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f133f08-5998-67f3-8003-4ddd7f24492d'}}, metadata={'source': 'loop', 'step': 3, 'parents': {}}, created_at='2026-04-09T08:45:55.179518+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f133f08-5998-67f2-8002-5839edc1545d'}}, tasks=(PregelTask(id='0a0ebf3c-59ef-8622-238a-90594c536a72', name='Node2', path=('__pregel_pull', 'Node2'), error=None, interrupts=(), state=None, result={'lnode': 'node_2', 'count': 1}),), interrupts=())
#
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hi', 'count': 2}, next=('Node1',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f133f08-5998-67f2-8002-5839edc1545d'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-04-09T08:45:55.179518+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f133f08-5993-6fa7-8001-a99d9d9cb826'}}, tasks=(PregelTask(id='8546218f-a4e2-5ca1-079a-b4b9c53659c1', name='Node1', path=('__pregel_pull', 'Node1'), error=None, interrupts=(), state=None, result={'lnode': 'node_1', 'count': 1}),), interrupts=())
#
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hi', 'count': 1}, next=('Node2',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f133f08-5993-6fa7-8001-a99d9d9cb826'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-04-09T08:45:55.177667+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f133f08-598d-6f37-8000-b5159010a485'}}, tasks=(PregelTask(id='60c81e20-ddd6-94ee-7bbf-0dd47ef77892', name='Node2', path=('__pregel_pull', 'Node2'), error=None, interrupts=(), state=None, result={'lnode': 'node_2', 'count': 1}),), interrupts=())
#
# StateSnapshot(values={'scratch': 'hi', 'count': 0}, next=('Node1',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f133f08-598d-6f37-8000-b5159010a485'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2026-04-09T08:45:55.175199+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f133f08-598c-6b6c-bfff-9fffab9362f0'}}, tasks=(PregelTask(id='608c2d57-78e3-9a39-84a6-f418c0ec869b', name='Node1', path=('__pregel_pull', 'Node1'), error=None, interrupts=(), state=None, result={'lnode': 'node_1', 'count': 1}),), interrupts=())
#
# StateSnapshot(values={'count': 0}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f133f08-598c-6b6c-bfff-9fffab9362f0'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2026-04-09T08:45:55.174692+00:00', parent_config=None, tasks=(PregelTask(id='11391d77-cc6e-4880-4c38-18a83937ca16', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'count': 0, 'scratch': 'hi'}),), interrupts=())

# %% [markdown]
# Store just the `config` into an list. Note the sequence of counts on the right. `get_state_history` returns the most recent snapshots first.

# %%
states = []
for state in graph.get_state_history(thread):
    states.append(state.config)
    print(state.config, state.values['count'])
# Out:
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f133f08-5999-6ba7-8004-6b9cec0059f9'}} 4
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f133f08-5998-67f3-8003-4ddd7f24492d'}} 3
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f133f08-5998-67f2-8002-5839edc1545d'}} 2
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f133f08-5993-6fa7-8001-a99d9d9cb826'}} 1
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f133f08-598d-6f37-8000-b5159010a485'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f133f08-598c-6b6c-bfff-9fffab9362f0'}} 0

# %% [markdown]
# Grab an early state.

# %%
states[-3]
# Out:
# {'configurable': {'thread_id': '1',
#   'checkpoint_ns': '',
#   'checkpoint_id': '1f133f08-5993-6fa7-8001-a99d9d9cb826'}}

# %% [markdown]
# This is the state after Node1 completed for the first time. Note `next` is `Node2`and `count` is 1.

# %%
graph.get_state(states[-3])
# Out:
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hi', 'count': 1}, next=('Node2',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f133f08-5993-6fa7-8001-a99d9d9cb826'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-04-09T08:45:55.177667+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f133f08-598d-6f37-8000-b5159010a485'}}, tasks=(PregelTask(id='60c81e20-ddd6-94ee-7bbf-0dd47ef77892', name='Node2', path=('__pregel_pull', 'Node2'), error=None, interrupts=(), state=None, result={'lnode': 'node_2', 'count': 1}),), interrupts=())

# %% [markdown]
# ### Go Back in Time
# Use that state in `invoke` to go back in time. Notice it uses states[-3] as *current_state* and continues to node2,

# %%
graph.invoke(None, states[-3])
# Out:
# node2, count:1
# node1, count:2
# node2, count:3
# {'lnode': 'node_2', 'scratch': 'hi', 'count': 4}

# %% [markdown]
# Notice the new states are now in state history. Notice the counts on the far right.

# %%
thread = {"configurable": {"thread_id": str(1)}}
for state in graph.get_state_history(thread):
    print(state.config, state.values['count'])
# Out:
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f133f08-5a42-62fa-8004-d09898b6c082'}} 4
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f133f08-5a42-62f9-8003-3743b02e1f0a'}} 3
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f133f08-5a3f-68a5-8002-2610ea7c8f64'}} 2
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f133f08-5999-6ba7-8004-6b9cec0059f9'}} 4
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f133f08-5998-67f3-8003-4ddd7f24492d'}} 3
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f133f08-5998-67f2-8002-5839edc1545d'}} 2
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f133f08-5993-6fa7-8001-a99d9d9cb826'}} 1
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f133f08-598d-6f37-8000-b5159010a485'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f133f08-598c-6b6c-bfff-9fffab9362f0'}} 0

# %% [markdown]
# You can see the details below. Lots of text, but try to find the node that start the new branch. Notice the parent *config* is not the previous entry in the stack, but is the entry from state[-3].

# %%
thread = {"configurable": {"thread_id": str(1)}}
for state in graph.get_state_history(thread):
    print(state,"\n")
# Out:
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hi', 'count': 4}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f133f08-5a42-62fa-8004-d09898b6c082'}}, metadata={'source': 'loop', 'step': 4, 'parents': {}}, created_at='2026-04-09T08:45:55.249023+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f133f08-5a42-62f9-8003-3743b02e1f0a'}}, tasks=(), interrupts=())
#
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hi', 'count': 3}, next=('Node2',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f133f08-5a42-62f9-8003-3743b02e1f0a'}}, metadata={'source': 'loop', 'step': 3, 'parents': {}}, created_at='2026-04-09T08:45:55.249023+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f133f08-5a3f-68a5-8002-2610ea7c8f64'}}, tasks=(PregelTask(id='14f8d899-fa69-398e-7ab8-dba39c7a1c43', name='Node2', path=('__pregel_pull', 'Node2'), error=None, interrupts=(), state=None, result={'lnode': 'node_2', 'count': 1}),), interrupts=())
#
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hi', 'count': 2}, next=('Node1',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f133f08-5a3f-68a5-8002-2610ea7c8f64'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-04-09T08:45:55.247939+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f133f08-5993-6fa7-8001-a99d9d9cb826'}}, tasks=(PregelTask(id='4e1477e1-3d23-6d93-718e-225f3f02b4ee', name='Node1', path=('__pregel_pull', 'Node1'), error=None, interrupts=(), state=None, result={'lnode': 'node_1', 'count': 1}),), interrupts=())
#
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hi', 'count': 4}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f133f08-5999-6ba7-8004-6b9cec0059f9'}}, metadata={'source': 'loop', 'step': 4, 'parents': {}}, created_at='2026-04-09T08:45:55.180023+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f133f08-5998-67f3-8003-4ddd7f24492d'}}, tasks=(), interrupts=())
#
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hi', 'count': 3}, next=('Node2',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f133f08-5998-67f3-8003-4ddd7f24492d'}}, metadata={'source': 'loop', 'step': 3, 'parents': {}}, created_at='2026-04-09T08:45:55.179518+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f133f08-5998-67f2-8002-5839edc1545d'}}, tasks=(PregelTask(id='0a0ebf3c-59ef-8622-238a-90594c536a72', name='Node2', path=('__pregel_pull', 'Node2'), error=None, interrupts=(), state=None, result={'lnode': 'node_2', 'count': 1}),), interrupts=())
#
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hi', 'count': 2}, next=('Node1',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f133f08-5998-67f2-8002-5839edc1545d'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-04-09T08:45:55.179518+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f133f08-5993-6fa7-8001-a99d9d9cb826'}}, tasks=(PregelTask(id='8546218f-a4e2-5ca1-079a-b4b9c53659c1', name='Node1', path=('__pregel_pull', 'Node1'), error=None, interrupts=(), state=None, result={'lnode': 'node_1', 'count': 1}),), interrupts=())
#
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hi', 'count': 1}, next=('Node2',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f133f08-5993-6fa7-8001-a99d9d9cb826'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-04-09T08:45:55.177667+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f133f08-598d-6f37-8000-b5159010a485'}}, tasks=(PregelTask(id='60c81e20-ddd6-94ee-7bbf-0dd47ef77892', name='Node2', path=('__pregel_pull', 'Node2'), error=None, interrupts=(), state=None, result={'lnode': 'node_2', 'count': 1}),), interrupts=())
#
# StateSnapshot(values={'scratch': 'hi', 'count': 0}, next=('Node1',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f133f08-598d-6f37-8000-b5159010a485'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2026-04-09T08:45:55.175199+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f133f08-598c-6b6c-bfff-9fffab9362f0'}}, tasks=(PregelTask(id='608c2d57-78e3-9a39-84a6-f418c0ec869b', name='Node1', path=('__pregel_pull', 'Node1'), error=None, interrupts=(), state=None, result={'lnode': 'node_1', 'count': 1}),), interrupts=())
#
# StateSnapshot(values={'count': 0}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f133f08-598c-6b6c-bfff-9fffab9362f0'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2026-04-09T08:45:55.174692+00:00', parent_config=None, tasks=(PregelTask(id='11391d77-cc6e-4880-4c38-18a83937ca16', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'count': 0, 'scratch': 'hi'}),), interrupts=())

# %% [markdown]
# ### Modify State
# Let's start by starting a fresh thread and running to clean out history.

# %%
thread2 = {"configurable": {"thread_id": str(2)}}
graph.invoke({"count":0, "scratch":"hi"},thread2)
# Out:
# node1, count:0
# node2, count:1
# node1, count:2
# node2, count:3
# {'lnode': 'node_2', 'scratch': 'hi', 'count': 4}

# %%
from IPython.display import Image

Image(graph.get_graph().draw_mermaid_png())

# %%
states2 = []
for state in graph.get_state_history(thread2):
    states2.append(state.config)
    print(state.config, state.values['count'])
# Out:
# {'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f133f08-5ab2-6167-8004-99ad1c8d97dc'}} 4
# {'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f133f08-5aaf-6a3b-8003-03e35c8c26e7'}} 3
# {'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f133f08-5aaf-6a3a-8002-e80e7569a30c'}} 2
# {'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f133f08-5aaa-60a4-8001-0e59a9dc522d'}} 1
# {'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f133f08-5aa7-697d-8000-f61058f2a299'}} 0
# {'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f133f08-5aa5-62ac-bfff-f9251a296beb'}} 0

# %% [markdown]
# Start by grabbing a state.

# %%
save_state = graph.get_state(states2[-3])
save_state
# Out:
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hi', 'count': 1}, next=('Node2',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f133f08-5aaa-60a4-8001-0e59a9dc522d'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-04-09T08:45:55.291562+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f133f08-5aa7-697d-8000-f61058f2a299'}}, tasks=(PregelTask(id='6ce6239a-750b-3c3b-6609-6cae41e01192', name='Node2', path=('__pregel_pull', 'Node2'), error=None, interrupts=(), state=None, result={'lnode': 'node_2', 'count': 1}),), interrupts=())

# %% [markdown]
# Now modify the values. One subtle item to note: Recall when agent state was defined, `count` used `operator.add` to indicate that values are *added* to the current value. Here, `-3` will be added to the current count value rather than replace it.

# %%
save_state.values["count"] = -3
save_state.values["scratch"] = "hello"
save_state
# Out:
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hello', 'count': -3}, next=('Node2',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f133f08-5aaa-60a4-8001-0e59a9dc522d'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-04-09T08:45:55.291562+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f133f08-5aa7-697d-8000-f61058f2a299'}}, tasks=(PregelTask(id='6ce6239a-750b-3c3b-6609-6cae41e01192', name='Node2', path=('__pregel_pull', 'Node2'), error=None, interrupts=(), state=None, result={'lnode': 'node_2', 'count': 1}),), interrupts=())

# %% [markdown]
# Now update the state. This creates a new entry at the *top*, or *latest* entry in memory. This will become the current state.

# %%
graph.update_state(thread2,save_state.values)
# Out:
# {'configurable': {'thread_id': '2',
#   'checkpoint_ns': '',
#   'checkpoint_id': '1f133f09-b1b5-6567-8005-9fdcf08692f8'}}

# %% [markdown]
# Current state is at the top. You can match the `thread_ts`.
# Notice the `parent_config`, `thread_ts` of the new node - it is the previous node.

# %%
for i, state in enumerate(graph.get_state_history(thread2)):
    if i >= 3:  #print latest 3
        break
    print(state, '\n')
# Out:
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hello', 'count': 1}, next=('Node1',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f133f09-b1b5-6567-8005-9fdcf08692f8'}}, metadata={'source': 'update', 'step': 5, 'parents': {}}, created_at='2026-04-09T08:46:31.262346+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f133f08-5ab2-6167-8004-99ad1c8d97dc'}}, tasks=(PregelTask(id='36836a81-db87-efb3-be3d-aea2dd9955f5', name='Node1', path=('__pregel_pull', 'Node1'), error=None, interrupts=(), state=None, result=None),), interrupts=())
#
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hi', 'count': 4}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f133f08-5ab2-6167-8004-99ad1c8d97dc'}}, metadata={'source': 'loop', 'step': 4, 'parents': {}}, created_at='2026-04-09T08:45:55.294858+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f133f08-5aaf-6a3b-8003-03e35c8c26e7'}}, tasks=(), interrupts=())
#
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hi', 'count': 3}, next=('Node2',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f133f08-5aaf-6a3b-8003-03e35c8c26e7'}}, metadata={'source': 'loop', 'step': 3, 'parents': {}}, created_at='2026-04-09T08:45:55.293855+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f133f08-5aaf-6a3a-8002-e80e7569a30c'}}, tasks=(PregelTask(id='685fb26c-86bc-d1f3-5cea-dc0922b94fe1', name='Node2', path=('__pregel_pull', 'Node2'), error=None, interrupts=(), state=None, result={'lnode': 'node_2', 'count': 1}),), interrupts=())

# %% [markdown]
# ### Try again with `as_node`
# When writing using `update_state()`, you want to define to the graph logic which node should be assumed as the writer. What this does is allow th graph logic to find the node on the graph. After writing the values, the `next()` value is computed by travesing the graph using the new state. In this case, the state we have was written by `Node1`. The graph can then compute the next state as being `Node2`. Note that in some graphs, this may involve going through conditional edges!  Let's try this out.

# %%
graph.update_state(thread2,save_state.values, as_node="Node1")
# Out:
# {'configurable': {'thread_id': '2',
#   'checkpoint_ns': '',
#   'checkpoint_id': '1f133f09-b1ef-6776-8006-1dd2ffbd5948'}}

# %%
for i, state in enumerate(graph.get_state_history(thread2)):
    if i >= 3:  #print latest 3
        break
    print(state, '\n')
# Out:
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hello', 'count': -2}, next=('Node2',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f133f09-b1ef-6776-8006-1dd2ffbd5948'}}, metadata={'source': 'update', 'step': 6, 'parents': {}}, created_at='2026-04-09T08:46:31.286155+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f133f09-b1b5-6567-8005-9fdcf08692f8'}}, tasks=(PregelTask(id='01682cbf-79bb-7dfd-2721-779c98124a7f', name='Node2', path=('__pregel_pull', 'Node2'), error=None, interrupts=(), state=None, result=None),), interrupts=())
#
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hello', 'count': 1}, next=('Node1',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f133f09-b1b5-6567-8005-9fdcf08692f8'}}, metadata={'source': 'update', 'step': 5, 'parents': {}}, created_at='2026-04-09T08:46:31.262346+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f133f08-5ab2-6167-8004-99ad1c8d97dc'}}, tasks=(PregelTask(id='36836a81-db87-efb3-be3d-aea2dd9955f5', name='Node1', path=('__pregel_pull', 'Node1'), error=None, interrupts=(), state=None, result={'lnode': 'node_1', 'scratch': 'hello', 'count': -3}),), interrupts=())
#
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hi', 'count': 4}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f133f08-5ab2-6167-8004-99ad1c8d97dc'}}, metadata={'source': 'loop', 'step': 4, 'parents': {}}, created_at='2026-04-09T08:45:55.294858+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f133f08-5aaf-6a3b-8003-03e35c8c26e7'}}, tasks=(), interrupts=())

# %% [markdown]
# `invoke` will run from the current state if not given a particular `thread_ts`. This is now the entry that was just added.

# %%
graph.invoke(None,thread2)
# Out:
# node2, count:-2
# node1, count:-1
# node2, count:0
# node1, count:1
# node2, count:2
# {'lnode': 'node_2', 'scratch': 'hello', 'count': 3}

# %% [markdown]
# Print out the state history, notice the `scratch` value change on the latest entries.

# %%
for state in graph.get_state_history(thread2):
    print(state,"\n")
# Out:
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hello', 'count': 3}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f133f09-b230-65d4-800b-24092b7aa195'}}, metadata={'source': 'loop', 'step': 11, 'parents': {}}, created_at='2026-04-09T08:46:31.312737+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f133f09-b230-65d3-800a-92461e331548'}}, tasks=(), interrupts=())
#
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hello', 'count': 2}, next=('Node2',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f133f09-b230-65d3-800a-92461e331548'}}, metadata={'source': 'loop', 'step': 10, 'parents': {}}, created_at='2026-04-09T08:46:31.312737+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f133f09-b22d-6ed5-8009-c3245f384964'}}, tasks=(PregelTask(id='56edc4a6-d3e3-3fe9-57d2-b48cafbbb721', name='Node2', path=('__pregel_pull', 'Node2'), error=None, interrupts=(), state=None, result={'lnode': 'node_2', 'count': 1}),), interrupts=())
#
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hello', 'count': 1}, next=('Node1',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f133f09-b22d-6ed5-8009-c3245f384964'}}, metadata={'source': 'loop', 'step': 9, 'parents': {}}, created_at='2026-04-09T08:46:31.311739+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f133f09-b22b-644c-8008-a939d6c9bad5'}}, tasks=(PregelTask(id='90ba3bb4-4902-d197-b647-591860327cc8', name='Node1', path=('__pregel_pull', 'Node1'), error=None, interrupts=(), state=None, result={'lnode': 'node_1', 'count': 1}),), interrupts=())
#
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hello', 'count': 0}, next=('Node2',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f133f09-b22b-644c-8008-a939d6c9bad5'}}, metadata={'source': 'loop', 'step': 8, 'parents': {}}, created_at='2026-04-09T08:46:31.310650+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f133f09-b226-6636-8007-fcab95fa763c'}}, tasks=(PregelTask(id='86cd0dbf-5a7a-a3d5-1183-80b66581f11b', name='Node2', path=('__pregel_pull', 'Node2'), error=None, interrupts=(), state=None, result={'lnode': 'node_2', 'count': 1}),), interrupts=())
#
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hello', 'count': -1}, next=('Node1',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f133f09-b226-6636-8007-fcab95fa763c'}}, metadata={'source': 'loop', 'step': 7, 'parents': {}}, created_at='2026-04-09T08:46:31.308651+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f133f09-b1ef-6776-8006-1dd2ffbd5948'}}, tasks=(PregelTask(id='b39ba78d-fb0d-de5e-f7a9-1828e09fec25', name='Node1', path=('__pregel_pull', 'Node1'), error=None, interrupts=(), state=None, result={'lnode': 'node_1', 'count': 1}),), interrupts=())
#
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hello', 'count': -2}, next=('Node2',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f133f09-b1ef-6776-8006-1dd2ffbd5948'}}, metadata={'source': 'update', 'step': 6, 'parents': {}}, created_at='2026-04-09T08:46:31.286155+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f133f09-b1b5-6567-8005-9fdcf08692f8'}}, tasks=(PregelTask(id='01682cbf-79bb-7dfd-2721-779c98124a7f', name='Node2', path=('__pregel_pull', 'Node2'), error=None, interrupts=(), state=None, result={'lnode': 'node_2', 'count': 1}),), interrupts=())
#
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hello', 'count': 1}, next=('Node1',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f133f09-b1b5-6567-8005-9fdcf08692f8'}}, metadata={'source': 'update', 'step': 5, 'parents': {}}, created_at='2026-04-09T08:46:31.262346+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f133f08-5ab2-6167-8004-99ad1c8d97dc'}}, tasks=(PregelTask(id='36836a81-db87-efb3-be3d-aea2dd9955f5', name='Node1', path=('__pregel_pull', 'Node1'), error=None, interrupts=(), state=None, result={'lnode': 'node_1', 'scratch': 'hello', 'count': -3}),), interrupts=())
#
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hi', 'count': 4}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f133f08-5ab2-6167-8004-99ad1c8d97dc'}}, metadata={'source': 'loop', 'step': 4, 'parents': {}}, created_at='2026-04-09T08:45:55.294858+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f133f08-5aaf-6a3b-8003-03e35c8c26e7'}}, tasks=(), interrupts=())
#
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hi', 'count': 3}, next=('Node2',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f133f08-5aaf-6a3b-8003-03e35c8c26e7'}}, metadata={'source': 'loop', 'step': 3, 'parents': {}}, created_at='2026-04-09T08:45:55.293855+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f133f08-5aaf-6a3a-8002-e80e7569a30c'}}, tasks=(PregelTask(id='685fb26c-86bc-d1f3-5cea-dc0922b94fe1', name='Node2', path=('__pregel_pull', 'Node2'), error=None, interrupts=(), state=None, result={'lnode': 'node_2', 'count': 1}),), interrupts=())
#
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hi', 'count': 2}, next=('Node1',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f133f08-5aaf-6a3a-8002-e80e7569a30c'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-04-09T08:45:55.293855+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f133f08-5aaa-60a4-8001-0e59a9dc522d'}}, tasks=(PregelTask(id='1caa622a-1244-1b6f-e263-94795d0d2f30', name='Node1', path=('__pregel_pull', 'Node1'), error=None, interrupts=(), state=None, result={'lnode': 'node_1', 'count': 1}),), interrupts=())
#
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hi', 'count': 1}, next=('Node2',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f133f08-5aaa-60a4-8001-0e59a9dc522d'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-04-09T08:45:55.291562+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f133f08-5aa7-697d-8000-f61058f2a299'}}, tasks=(PregelTask(id='6ce6239a-750b-3c3b-6609-6cae41e01192', name='Node2', path=('__pregel_pull', 'Node2'), error=None, interrupts=(), state=None, result={'lnode': 'node_2', 'count': 1}),), interrupts=())
#
# StateSnapshot(values={'scratch': 'hi', 'count': 0}, next=('Node1',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f133f08-5aa7-697d-8000-f61058f2a299'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2026-04-09T08:45:55.290559+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f133f08-5aa5-62ac-bfff-f9251a296beb'}}, tasks=(PregelTask(id='aca551e8-22e3-0aa6-b383-a57acc8aab41', name='Node1', path=('__pregel_pull', 'Node1'), error=None, interrupts=(), state=None, result={'lnode': 'node_1', 'count': 1}),), interrupts=())
#
# StateSnapshot(values={'count': 0}, next=('__start__',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f133f08-5aa5-62ac-bfff-f9251a296beb'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2026-04-09T08:45:55.289565+00:00', parent_config=None, tasks=(PregelTask(id='3218d260-6c01-f944-dd9a-7d1d3dbd2651', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'count': 0, 'scratch': 'hi'}),), interrupts=())

# %% [markdown]
# Continue to experiment!
